# %% [markdown]
# # Лабораторная работа 2. Циклы и списки.

# %% [markdown]
# # Справочная информация:

# %% [markdown]
# # 1. Типы данных

# %% [markdown]
# Основными типами данных в любом языке программирования являются:
#
# целые числа, вещественные числа, строки (символы), логические переменные (True (истина) или False (ложь)).
#
# Они могут быть записаны следующим образом

# %%
print(1, 1.0, '1', 1<2, 2<1)
# Out:
# 1 1.0 1 True False

# %% [markdown]
# Функцией type возвращает тип аргумента:

# %%
(type(1), type(1.0), type('1'), type(1<2), type(2<1))
# Out:
# (int, float, str, bool, bool)

# %% [markdown]
# # 1.2 Операции с числами: $A+B$, $A-B$, $A*B$, $A/B$, $A^B$

# %%
# комментарий: с целыми числами
A=1 
B=2
print (' A + B = ',A+B) # сумма
print (' A - B = ',A-B) # разность;
print (' A * B = ',A*B) # произведение;
print (' A / B = ',A/B) # частное;
print (' A ^ B = ',A**B) # возведение в степень.
# Out:
#  A + B =  3
#  A - B =  -1
#  A * B =  2
#  A / B =  0.5
#  A ^ B =  1

# %%
# комментарий: с вещественными числами
A=1.0 
B=2.0
print (' A + B  = ',A+B)  # сумма
print (' A - B  = ',A-B)  # разность;
print (' A * B  = ',A*B)  # произведение;
print (' A / B  = ',A/B)  # частное;
print (' A % B  = ',A%B)  #  остаток от деления;
print (' A // B = ',A//B) # деление без остатка;
print (' A ^ B  = ',A**B) # возведение в степень.
# Out:
#  A + B  =  3.0
#  A - B  =  -1.0
#  A * B  =  2.0
#  A / B  =  0.5
#  A % B  =  1.0
#  A // B =  0.0
#  A ^ B  =  1.0

# %%
# комментарий: ещё о целых числах, без автоматического переопределения типа было бы так
A=1
B=2
print (' A / B = ',A/B, 'возвращаемый тип - ', type(A/B)) # автоматическое переопределение;
print (' A / B = ',(int)(A/B), 'возвращаемый тип - ', type((int)(A/B))) # без автоматического переопределения;
# Out:
#  A / B =  0.5 возвращаемый тип -  <class 'float'>
#  A / B =  0 возвращаемый тип -  <class 'int'>

# %% [markdown]
# # 1.2 Операции над строками

# %%
Ast=' я люблю ' 
Bst=' информатику '
n=3
print (' Ast + Bst = ',Ast+'и'+Bst)  # конкатенация 
print ('(Ast + Bst) * n = ',(Ast+Bst)*n)  # повторение n раз
# Out:
#  Ast + Bst =   я люблю и информатику
# (Ast + Bst) * n =   я люблю  информатику  я люблю  информатику  я люблю  информатику

# %% [markdown]
# # 1.3 Логические операции

# %%
A=1.0 
B=2.0
print (' A >  B  ? ',A>B)   # больше
print (' A <  B  ? ',A<B)   # меньша
print (' A >= B  ? ',A>=B)  # больше или равно
print (' A <= B  ? ',A<=B)  # меньше или равно
print (' A == B  ? ',A==B)  # равно
print (' A != B ? ',A!=B)   # не равно
print (' A < B < A+B ? ',A<B<A+B) # из интервала
print (' A < B и B < A+B  ? ',A<B and B<A+B) # и (*)
print (' A < B или A > B  ? ',A<B or A>B) # или (+)

print ('\n',A<B , A>B, A<B * A>B, A<B + A>B)  # \n - знак перехода на строку

print ('\n',bool(1), '\t', bool(0))  # \t - знак табуляции
# Out:
#  A >  B  ?  False
#  A <  B  ?  True
#  A >= B  ?  False
#  A <= B  ?  True
#  A == B  ?  False
#  A != B ?  True
#  A < B < A+B ?  True
#  A < B и B < A+B  ?  True
#  A < B или A > B  ?  True
#
#  True False False True
#
#  True 	 False

# %% [markdown]
# # 2 Основные инструкции

# %% [markdown]
# # 2.1 Операции ввода/вывода

# %% [markdown]
# Форматный вывод (это красиво): %ШиринаПоля.ТочностьТип
#
# % - указатель на вставку, тип: i - int, f - float, s - str, e - "научное" представление, g - "компактное" представление десятичного числа
#
# По умолчанию производится выравнивание по правому краю, для выравневания по левому нужно писать %- вместо %.
#
# (Кроме того, существует метод str.format() для форматного вывода строк.)

# %%
A=1 
B=2
print(" A / B = %6.4f, возвращаемый тип - %s " % (A/B, type(A/B)))
print(" A / B = %-6i, возвращаемый тип - %s " % ((int)(A/B), type((int)(A/B))))
# Out:
#  A / B = 0.5000, возвращаемый тип - <class 'float'>
#  A / B = 0     , возвращаемый тип - <class 'int'>

# %% [markdown]
# В интерактивной сессии (или в программе, запущенной с командной строки) можно попросить пользователя что-нибудь ввести. Аргумент функции input - это приглашение для ввода (prompt). Можно использовать просто input(), тогда приглашения не будет. Но это неудобно, т.к. в этом случае трудно заметить, что программа чего-то ждёт.

# %%
s=input('Введите число ')
print('s = ', s, type(s))
sf=float(s)
print('sf = ', sf, type(sf))
# Out:
# Введите число 1
# s =  1 <class 'str'>
# sf =  1.0 <class 'float'>

# %% [markdown]
# Питон - интерпретатор, поэтому он может во время выполнения программы интерпретировать строки как куски исходного текста на языке питон. Так, функция eval интерпретирует строку как выражение и вычисляет его (в текущем контексте - подставляя текущие значения переменных).

# %%
s=input('Введите операцию с переменной sf')
print('s = ', s, type(s))
print(s + ' = ', eval(s))
# Out:
# Введите операцию с переменной sf1+sf
# s =  1+sf <class 'str'>
# 1+sf =  2.0

# %% [markdown]
# А функция exec интерпретирует строку как оператор и выполняет его. Оператор может менять значения переменных в текущем пространстве имён.

# %%
s=input('Введите выражение с переменной sf ')
# Out:
# Введите выражение с переменной sf x = sf**2+sf

# %%
s
# Out:
# 'x = sf**2+sf'

# %%
exec(s)
print(x)
# Out:
# 2.0

# %% [markdown]
# # 2.2 Ветвление (или условная инструкция)

# %% [raw]
# Синтаксис:
#
# if Условие1:
#     Блок_инструкций_1 (выполняется если условие1 выполнено)
# elif Условие2:
#     Блок_инструкций_2 (выполняется если условие2 выполнено)
# else:
#     Блок_инструкций_3 (выполняется если условия не выполнены)
#
# или болеее компатно:
#
# A = инструкция1(выполняется когда верно условие) if условие else инструкция2

# %%
# Пример

a = input('Введите целое число a: ') 
b = input('Введите целое число b: ') 

if a < b: 
    print ('a - наименьшее из двух чисел') 
elif a == b: 
    print ('a и b равны')
else: 
    print ('b - наименьшее из двух чисел')
# Out:
# Введите целое число a: 1
# Введите целое число b: 2
# a - наименьшее из двух чисел

# %%
a = input('Введите целое число a: ') 
b = input('Введите целое число b: ') 

print ('a - наименьшее из двух чисел') if a<b else (print ('b - наименьшее из двух чисел') if a>b else print ('a и b равны'))
# Out:
# a - наименьшее из двух чисел

# %% [markdown]
# # 2.3 Цикл

# %% [raw]
# Цикл while («пока») позволяет выполнить одну и ту же последовательность действий, пока проверяемое условие истинно. Условие записывается до тела цикла и проверяется до выполнения тела цикла. Как правило, цикл while используется, когда невозможно определить точное значение количества проходов исполнения цикла.
#
# Синтаксис цикла while:
#
# while Условие:
#     Блок_инструкций

# %% [raw]
# АлдабаеваЦикл for
#
# Синтаксис:
#
# for i in range(10):      #   for i in range(от, до, шаг):
#     Блок_инструкций
#
# эквивалентно:
#
# i = 0
# while i < 10:
#     Блок_инструкций
#     i += 1

# %% [markdown]
# # 2.4 Обработка ошибок

# %% [raw]
# try:
#     Блок_инструкций_1
# except:
#     Блок_инструкций_2 (выполняется в случае ошибки в Блок_инструкций_1)

# %% [markdown]
# # 3 Функции

# %% [markdown]
# Простейшая в мире функция: не имеет параметров, ничего не делает и ничего не возвращает. Оператор pass означает "ничего не делай"; он используется там, где синтаксически необходим оператор, а делать ничено не нужно (после if или elif, после def и т.д.).

# %%
def fun0():
    pass

# %%
fun0()

# %% [markdown]
# # Пример 1. "Сравнение двух чисел"

# %% [markdown]
# Рассмотрим программу которая умеет сравнивать два числа.
# Логика её работы приведена ниже.

# %%
# Так можно добавлять картинки

from IPython.display import Image              # вызов из библиотеки определённой функции
Image("Схема сравнения чисел.png")             # вызов функции и передача ей в качестве аргумента пути к файлу 

# (в данном случае фаил находится в той же папке)

# %%
a = input('Введите целое число a: ')
b = input('Введите целое число b: ')

if a < b: 
    print ('a - наименьшее из двух чисел') 
elif a == b: 
    print ('a и b равны')
else:
    print ('b - наименьшее из двух чисел')
# Out:
# Введите целое число a: 20
# Введите целое число b: 4
# a - наименьшее из двух чисел

# %% [markdown]
# # Упражнение 1. На сколько?

# %% [markdown]
# Добавьте в текст предыдущей программы вычисление разницы между этими числами и выводите эту информацию в сообщении с результатом.

# %%
a = input('Введите целое число a: ')
b = input('Введите целое число b: ')
a=float(a)
b=float(b)
if a < b: 
    print ('a - наименьшее из двух чисел ', b-a, '- разница чисел') 
elif a == b: 
    print ('a и b равны ', b-a, '- разница чисел')
else:
    print ('b - наименьшее из двух чисел ', a-b, '- разница чисел')
# Out:
# Введите целое число a: 5
# Введите целое число b: 8
# a - наименьшее из двух чисел  3.0 - разница чисел

# %% [markdown]
# # Упражнение 2. "Сравнение трёх чисел"

# %% [markdown]
# Добавьте к сравнению третье число и выведите результат с информацией о величине максимального и минимального числа.
#
# Какое наименьшее число операторов сравнения (>, <, >=, <=) необходимо для решения этой задачи?

# %%
a = input('Введите целое число a: ')
b = input('Введите целое число b: ')
c = input('Введите целое число c: ')
a=float(a)
b=float(b)
c=float(c)
if a>=b>=c:
    print(a," - max", c," - min")
elif a>=c>=b:
    print(a," - max", b," - min")
elif b>=c>=a:
    print(b," - max", a," - min")
elif b>=a>=c:
    print(b," - max", c," - min")
elif c>=a>=b:
    print(c," - max", b," - min")
else:
    print(c," - max", a," - min") #У меня получилось 10 операторов
# Out:
# Введите целое число a: 1
# Введите целое число b: 2
# Введите целое число c: 3
# 3.0  - max 1.0  - min

# %% [markdown]
# # Пример 2. "Метание мяча в деталях"

# %% [markdown]
# Рассмотрим пример иллюстрирующий математическую модель описывающий траекторию полета мяча в воздухе. Из второго закона Ньютона, предполагая отсутствие сопротивления воздуха, мы можем вывести зависимость вертикального положения мяча от времени $t$:
#
#
# $$y(t)=v_0t−\frac{1}{2}gt^2$$
#
#
# где $v_0$ — начальная скорость, $g$ — ускорение свободного падения, значение которого положим равным 9.80665 $м/c^2$.
#
# (Обратите внимание какие красивые формулы! Текстовые ячейки Jupiter поддерживают набор формул в синтаксесе вёрстки LaTeX, наиболее популярный набор макрорасширений (или макропакет) системы компьютерной вёрстки TeX.)

# %% [markdown]
# Теперь нас будет интересовать траектория полёта меча.

# %% [markdown]
# Зададим исходные данные:

# %%
# Программа для вычисления положения мяча при вертикальном движении

v0 = 5       # Начальная скорость
g = 9.80665  # Ускорение свободного падения

tmax = 2*v0/g

# %% [markdown]
# и определим несколько моментов времени.

# %% [markdown]
# До этого момента все наши переменные могли содержать только одно число, будь оно хоть целым (int), хоть с плавающей точкой (float). Но иногда числа естественным образом группируются. Например, последовательность моментов времени представляют собой группу. Для групп в Python есть несколько специальных типов объектов, рассмотрим тип — list (список), который позволяет организовывать эти группы в последовательности. При этом, с помощью списков мы можем работать как с группой целиком, так и с членами этой группы по отдельности. При этом список может состоять из объектов разного типа, в том числе и из самих списков.

# %%
t = [0, 1/4*tmax, 1/2*tmax, 3/4*tmax, tmax]      # список моментов времени

n = len(t)  #  функция len() определяет "длинну" списка (количество эллементов)

print("число моментов времени ", n)
# Out:
# число моментов времени  5

# %% [markdown]
# Организуем с помощью цикла for перебор этих моментов

# %%
for i in [0,1,2,3,4]:
    y = v0*t[i] - 1/2*g*t[i]**2
    print ("в момент времени %14.8e высота равна %14.8e" %(t[i], y))
# Out:
# в момент времени 0.00000000e+00 высота равна 0.00000000e+00
# в момент времени 2.54929053e-01 высота равна 9.55983950e-01
# в момент времени 5.09858106e-01 высота равна 1.27464527e+00
# в момент времени 7.64787160e-01 высота равна 9.55983950e-01
# в момент времени 1.01971621e+00 высота равна 0.00000000e+00

# %% [markdown]
# Теперь наша переменная t ссылается на объект типа list, который содержит последовательность. Все элементы в этом случае являются объектами типа int.
#
# Любой элемент в списке связан со своим индексом, который определяет позицию элемента в списке. Первый элемент имеет индекс 0, второй элемент — индекс 1 и так далее. Для того, чтобы вызвать какой-то элемент списка, достаточно вызвать его по индексу, например t[3].
#
# Элементы в списках можно удалять, добавлять, изменять, вставлять и так далее. Делается это с помощью методов. Методы определяются через точку.
#
# Например метод append для списка y запишется как y.append(v), и этот метод добавит элемент v в конец списка y. А метод y.insert(i,v) вставит новый элемент v на позицию i.

# %%
y=[] # создаем пустой список
for i in [0,1,2,3,4]:
    y.append(v0*t[i] - 1/2*g*t[i]**2) # дописываем значение в конец списка 

print (y, type(y))
# Out:
# [0.0, 0.9559839496668078, 1.2746452662224104, 0.9559839496668081, 0.0] <class 'list'>

# %% [markdown]
# Добавим ещё несколько моментов времени:

# %%
t.insert(1, 1/8*tmax)
t.insert(3, 3/8*tmax)
t.insert(5, 5/8*tmax)
t.insert(7, 7/8*tmax)

n = len(t)
print(t, n)
# Out:
# [0, 0.12746452662224103, 0.25492905324448206, 0.38239357986672307, 0.5098581064889641, 0.6373226331112052, 0.7647871597334461, 0.8922516863556872, 1.0197162129779282] 9

# %% [markdown]
# Вычислим значение y в новые моменты времени и вставим их список:

# %%
for i in [1,3,5,7]:
    y.insert(i,v0*t[i] - 1/2*g*t[i]**2) # дописываем значение в заданные позиции списка 

print (y)
# Out:
# [0.0, 0.5576573039723045, 0.9559839496668078, 1.1949799370835097, 1.2746452662224104, 1.1949799370835101, 0.9559839496668081, 0.557657303972305, 0.0]

# %% [markdown]
# С помощью del t[i] мы можем удалять любые элементы. Метод t.index(v) позволяет определить под каким индексом расположен интересующий нас элемент.

# %%
print(t)

del t[0]

print(t)
# Out:
# [0, 0.12746452662224103, 0.25492905324448206, 0.38239357986672307, 0.5098581064889641, 0.6373226331112052, 0.7647871597334461, 0.8922516863556872, 1.0197162129779282]
# [0.12746452662224103, 0.25492905324448206, 0.38239357986672307, 0.5098581064889641, 0.6373226331112052, 0.7647871597334461, 0.8922516863556872, 1.0197162129779282]

# %%
y.index(0)
# Out:
# 0

# %% [markdown]
# Поскольку прохождение по списку и создание соответствующего нового списка является часто встречаемой задачей, в Python имеется компактный синтаксис для решения этой проблемы, который часто называют генерацией списка. В общем виде это выглядит так:

# %%
n = 10
t = [i/n*t for i in range(n+1)]
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 n = 10
# ----> 2 t = [i/n*t for i in range(n+1)]
#       3 print(t)
#
# Input In [19], in <listcomp>(.0)
#       1 n = 10
# ----> 2 t = [i/n*t for i in range(n+1)]
#       3 print(t)
#
# NameError: name 't' is not defined

# %% [markdown]
# Вместо цикла for по заданным элементам списка мы можем использовать цикл for с генерированным списком индексов. Для этого в Python есть функция range, возвращающая список по порядку идущих чисел: range(от,до,шаг)

# %% [markdown]
# Модифициурем сценарий из 1-й лабораторной. Программа на Python с векторизацией и построением графиков для иллюстрации использования цикла for.
#
# Предположим, мы хотим найти максимальную высоту в течение этого времени. Один из вариантов реализации этого может быть следующим: вычисляем все тысяча значений высоты, сохраняем их в массив, а затем пробегаем весь массив, чтобы найти максимальное значение.

# %%
import numpy as np
import matplotlib.pyplot as plt

v0 = 5.0
g = 9.80665  # Ускорение свободного падения

tmax = 2*v0/g

t = np.linspace(0, tmax, 1000)
y = v0*t - 0.5*g*t**2

max_height = y[0]
for i in range(1, 1000):
    if y[i] > max_height:
        max_height = y[i]

print ('Максимальная достигнутая высота равна %f м' % (max_height))

plt.figure(figsize=(9,7))  

plt.plot(t, y)
plt.xlabel(u'Время (с)')
plt.ylabel(u'Высота (м)')
plt.show()
# Out:
# Максимальная достигнутая высота равна 1.274644 м

# %%
print ('Терерь последовательность t имеет %i эллементов и тип %s'%(len(t), type(t)))
# Out:
# Терерь последовательность t имеет 1000 эллементов и тип <class 'numpy.ndarray'>

# %% [markdown]
# Ещё одним удобным вариантом для группировки эллементов служат массиивы библиотеки numpy. Функция этой библиотеки linspace(от, до, количество эллементов) создает набор чисел с равным шагом из заданного диапазона

# %% [markdown]
# В языке Python имеется еще одна стандартная циклическая конструкция — цикл while. Для иллюстрации использования этого цикла рассмотрим другую модификацию сценария из лабораторной 1. Теперь мы изменим его так, чтобы сценарий находил время полета мяча. Предположим, что мы подбросили мяч с немного меньшей начальной скоростью 4.5 м/с. Так как мы будем рассматривать первую секунду полета, то высота в конце этого интервала будет отрицательной. Это означает, что мяч упал ниже своего начального положения. В нашем массиве y мы будем иметь ряд отрицательных значений, которые расположены в конце массива.
#
# В следующем сценарии находится момент времени, когда значение высоты становится отрицательным, т.е., когда мяч пересекается прямую y=0. Сценарий может быть следующим:

# %%
v0 = 4.5
g = 9.81
t = np.linspace(0, 1, 1000)
y = v0*t - 0.5*g*t**2

i = 0
while y[i] >= 0:
    i += 1

print (u'y = 0 в момент времени ', 0.5*(t[i-1] + t[i]))

plt.figure(figsize=(9,7))  

plt.plot(t, y)
plt.xlabel(u'Время (с)')
plt.ylabel(u'Высота (м)')
plt.show()
# Out:
# y = 0 в момент времени  0.9174174174174174

# %% [markdown]
# В приведенном примере Цикл while выполняется до тех пор, пока булевское выражение y[i] > 0 возвращает значение True. Отметим, что в этом случае счетчик цикла i введен и инициализирован (i = 0) до начала выполнения цикла и обновляется (i += 1) внутри цикла. Таким образом, для каждой итерации i явно увеличивается на 1.
#
# В отличие от цикла for, программист не должен определять количество итераций при использовании цикла while. Он просто выполняется пока булевское выражение не вернет значение False. Таким образом, в этом случае счетчик цикла не обязателен. Кроме того, если в цикле while используется счетчик, то он не увеличивается автоматически, это нужно делать явно. Конечно, как и в цикле for и в инструкции if может быть несколько строк кода в теле цикла while. Любой цикл for может быть реализован с помощью while, но циклы while являются более общими и не все из них можно реализовать с помощью for.
#
# Следует быть осторожным с так называемыми бесконечными циклами. Могут возникнуть (непреднамеренно) случаи, когда тест в инструкции while никогда не вернет значение False, и сценарий не сможет выйти из цикла.

# %% [markdown]
# # Упражнение 4. $\pi$

# %% [markdown]
# Число Пи - несомненно, одна из основных констант, значение которой было известно еще в древности. Оно используется везде, от кройки и шитья до расчетов гармонических колебаний в физике и радиотехнике.
#
# Но чему она равна? Есть ли у этого числа какая-то внутренняя структура, неизвестная закономерность? Узнать это хотели многие. Самый простой и очевидный способ - взять и измерить. Примерно так вероятно и поступали в древности, точность разумеется была невысокой. Еще в древнем Вавилоне значение числа Пи было известно как 25/8. Затем Архимед предложил первый математический метод вычисления числа Пи, с помощью расчета вписанных в круг многоугольников. Это позволяло вычислять значение не «напрямую», с циркулем и линейкой, а математически, что обеспечивало гораздо большую точность. И наконец в 3-м веке нашей эры китайский математик Лю Хуэй придумал первый итерационный алгоритм — алгоритм, в котором число вычисляется не одной формулой, а последовательностью шагов (итераций), где каждая последующая итерация увеличивает точность.
#
# Кроме того, число Пи является иррациональным: оно не может быть выражено с помощью дроби вида m/n. Это было доказано только в 1761 году. Число Пи является трансцендентным: оно не является корнем какого-либо уравнения с целочисленными коэффициентами. Это было доказано в 1882 году. Число Пи является бесконечным. Интересное следствие предыдущего пункта: в числе Пи можно найти практически любое число, например свой собственный номер телефона, вопрос лишь в длине последовательности которую придется просмотреть.
#
# Перейдем к формулам вычисления $\pi$:
#
# Формула Мадхавы-Лейбница (15 век):
#
# $$\frac{1}{1} - \frac{1}{3} + \frac{1}{5} - \frac{1}{7} + \frac{1}{9} - ... = \frac{\pi}{4}$$
#
# Формула Валлиса (17 век):
#
# $$\frac{2}{1} * \frac{2}{3} * \frac{4}{3} * \frac{4}{5} * \frac{6}{5} * \frac{6}{7} * \frac{8}{7} * \frac{8}{9} ... = \frac{\pi}{2}$$
#
# Напишите программу вычисляющее значение числа $\pi$ по этим формулам первые n итераций. Выводите все итерации и текущее значение числа $\pi$ с 10 знаками после запятой в следующеем формате:
#
# Номер итерации  ф. Мадхавы-Лейбница  ф. Валлиса

# %%
n=input()
n=int(n)
k=1
p=0
y=0
p1=4
c=2
z=3
for i in range(n):
    p+=(-1)**i*1/k*4
    k+=2
    y+=1
    print('номер итерации ф. Мадхавы-Лейбница - ', y, 'число пи = %10.10e' %(p))
    p1=p1*c/z
    h=z
    z=c+1
    c=h+1
    print('номер итерации ф. Валлиса - ', y, 'число пи = %10.10e' %(p1))
# Out:
# 1000
# номер итерации ф. Мадхавы-Лейбница -  1 число пи = 4.0000000000e+00
# номер итерации ф. Валлиса -  1 число пи = 2.6666666667e+00
# номер итерации ф. Мадхавы-Лейбница -  2 число пи = 2.6666666667e+00
# номер итерации ф. Валлиса -  2 число пи = 3.5555555556e+00
# номер итерации ф. Мадхавы-Лейбница -  3 число пи = 3.4666666667e+00
# номер итерации ф. Валлиса -  3 число пи = 2.8444444444e+00
# номер итерации ф. Мадхавы-Лейбница -  4 число пи = 2.8952380952e+00
# номер итерации ф. Валлиса -  4 число пи = 3.4133333333e+00
# номер итерации ф. Мадхавы-Лейбница -  5 число пи = 3.3396825397e+00
# номер итерации ф. Валлиса -  5 число пи = 2.9257142857e+00
# номер итерации ф. Мадхавы-Лейбница -  6 число пи = 2.9760461760e+00
# номер итерации ф. Валлиса -  6 число пи = 3.3436734694e+00
# номер итерации ф. Мадхавы-Лейбница -  7 число пи = 3.2837384837e+00
# номер итерации ф. Валлиса -  7 число пи = 2.9721541950e+00
# номер итерации ф. Мадхавы-Лейбница -  8 число пи = 3.0170718171e+00
# номер итерации ф. Валлиса -  8 число пи = 3.3023935500e+00
# номер итерации ф. Мадхавы-Лейбница -  9 число пи = 3.2523659347e+00
# номер итерации ф. Валлиса -  9 число пи = 3.0021759546e+00
# номер итерации ф. Мадхавы-Лейбница -  10 число пи = 3.0418396189e+00
# номер итерации ф. Валлиса -  10 число пи = 3.2751010413e+00
# номер итерации ф. Мадхавы-Лейбница -  11 число пи = 3.2323158094e+00
# номер итерации ф. Валлиса -  11 число пи = 3.0231701920e+00
# номер итерации ф. Мадхавы-Лейбница -  12 число пи = 3.0584027659e+00
# номер итерации ф. Валлиса -  12 число пи = 3.2557217452e+00
# номер итерации ф. Мадхавы-Лейбница -  13 число пи = 3.2184027659e+00
# номер итерации ф. Валлиса -  13 число пи = 3.0386736289e+00
# номер итерации ф. Мадхавы-Лейбница -  14 число пи = 3.0702546178e+00
# номер итерации ф. Валлиса -  14 число пи = 3.2412518708e+00
# номер итерации ф. Мадхавы-Лейбница -  15 число пи = 3.2081856523e+00
# номер итерации ф. Валлиса -  15 число пи = 3.0505899961e+00
# номер итерации ф. Мадхавы-Лейбница -  16 число пи = 3.0791533942e+00
# номер итерации ф. Валлиса -  16 число пи = 3.2300364664e+00
# номер итерации ф. Мадхавы-Лейбница -  17 число пи = 3.2003655154e+00
# номер итерации ф. Валлиса -  17 число пи = 3.0600345471e+00
# номер итерации ф. Мадхавы-Лейбница -  18 число пи = 3.0860798011e+00
# номер итерации ф. Валлиса -  18 число пи = 3.2210889970e+00
# номер итерации ф. Мадхавы-Лейбница -  19 число пи = 3.1941879092e+00
# номер итерации ф. Валлиса -  19 число пи = 3.0677038066e+00
# номер итерации ф. Мадхавы-Лейбница -  20 число пи = 3.0916238067e+00
# номер итерации ф. Валлиса -  20 число пи = 3.2137849403e+00
# номер итерации ф. Мадхавы-Лейбница -  21 число пи = 3.1891847823e+00
# номер итерации ф. Валлиса -  21 число пи = 3.0740551603e+00
# номер итерации ф. Мадхавы-Лейбница -  22 число пи = 3.0961615265e+00
# номер итерации ф. Валлиса -  22 число пи = 3.2077097325e+00
# номер итерации ф. Мадхавы-Лейбница -  23 число пи = 3.1850504154e+00
# номер итерации ф. Валлиса -  23 число пи = 3.0794013432e+00
# номер итерации ф. Мадхавы-Лейбница -  24 число пи = 3.0999440324e+00
# номер итерации ф. Валлиса -  24 число пи = 3.2025773969e+00
# номер итерации ф. Мадхавы-Лейбница -  25 число пи = 3.1815766854e+00
# номер итерации ф. Валлиса -  25 число пи = 3.0839634192e+00
# номер итерации ф. Мадхавы-Лейбница -  26 число пи = 3.1031453129e+00
# номер итерации ф. Валлиса -  26 число пи = 3.1981842866e+00
# номер итерации ф. Мадхавы-Лейбница -  27 число пи = 3.1786170110e+00
# номер итерации ф. Валлиса -  27 число пи = 3.0879020698e+00
# номер итерации ф. Мадхавы-Лейбница -  28 число пи = 3.1058897383e+00
# номер итерации ф. Валлиса -  28 число пи = 3.1943814515e+00
# номер итерации ф. Мадхавы-Лейбница -  29 число пи = 3.1760651769e+00
# номер итерации ф. Валлиса -  29 число пи = 3.0913368886e+00
# номер итерации ф. Мадхавы-Лейбница -  30 число пи = 3.1082685667e+00
# номер итерации ф. Валлиса -  30 число пи = 3.1910574334e+00
# номер итерации ф. Мадхавы-Лейбница -  31 число пи = 3.1738423372e+00
# номер итерации ф. Валлиса -  31 число пи = 3.0943587233e+00
# номер итерации ф. Мадхавы-Лейбница -  32 число пи = 3.1103502737e+00
# номер итерации ф. Валлиса -  32 число пи = 3.1881271694e+00
# номер итерации ф. Мадхавы-Лейбница -  33 число пи = 3.1718887352e+00
# номер итерации ф. Валлиса -  33 число пи = 3.0970378217e+00
# номер итерации ф. Мадхавы-Лейбница -  34 число пи = 3.1121872427e+00
# номер итерации ф. Валлиса -  34 число пи = 3.1855246167e+00
# номер итерации ф. Мадхавы-Лейбница -  35 число пи = 3.1701582572e+00
# номер итерации ф. Валлиса -  35 число пи = 3.0994293567e+00
# номер итерации ф. Мадхавы-Лейбница -  36 число пи = 3.1138202290e+00
# номер итерации ф. Валлиса -  36 число пи = 3.1831977177e+00
# номер итерации ф. Мадхавы-Лейбница -  37 число пи = 3.1686147496e+00
# номер итерации ф. Валлиса -  37 число пи = 3.1015772634e+00
# номер итерации ф. Мадхавы-Лейбница -  38 число пи = 3.1152814162e+00
# номер итерации ф. Валлиса -  38 число пи = 3.1811048856e+00
# номер итерации ф. Мадхавы-Лейбница -  39 число пи = 3.1672294682e+00
# номер итерации ф. Валлиса -  39 число пи = 3.1035169615e+00
# номер итерации ф. Мадхавы-Лейбница -  40 число пи = 3.1165965568e+00
# номер итерации ф. Валлиса -  40 число пи = 3.1792124972e+00
# номер итерации ф. Мадхавы-Лейбница -  41 число пи = 3.1659792728e+00
# номер итерации ф. Валлиса -  41 число пи = 3.1052773228e+00
# номер итерации ф. Мадхавы-Лейбница -  42 число пи = 3.1177865018e+00
# номер итерации ф. Валлиса -  42 число пи = 3.1774930745e+00
# номер итерации ф. Мадхавы-Лейбница -  43 число пи = 3.1648453253e+00
# номер итерации ф. Валлиса -  43 число пи = 3.1068821173e+00
# номер итерации ф. Мадхавы-Лейбница -  44 число пи = 3.1188683138e+00
# номер итерации ф. Валлиса -  44 число пи = 3.1759239421e+00
# номер итерации ф. Мадхавы-Лейбница -  45 число пи = 3.1638121340e+00
# номер итерации ф. Валлиса -  45 число пи = 3.1083510923e+00
# номер итерации ф. Мадхавы-Лейбница -  46 число пи = 3.1198560901e+00
# номер итерации ф. Валлиса -  46 число пи = 3.1744862219e+00
# номер итерации ф. Мадхавы-Лейбница -  47 число пи = 3.1628668428e+00
# номер итерации ф. Валлиса -  47 число пи = 3.1097007888e+00
# номер итерации ф. Мадхавы-Лейбница -  48 число пи = 3.1207615796e+00
# номер итерации ф. Валлиса -  48 число пи = 3.1731640702e+00
# номер итерации ф. Мадхавы-Лейбница -  49 число пи = 3.1619986930e+00
# номер итерации ф. Валлиса -  49 число пи = 3.1109451669e+00
# номер итерации ф. Мадхавы-Лейбница -  50 число пи = 3.1215946526e+00
# номер итерации ф. Валлиса -  50 число пи = 3.1719440917e+00
# номер итерации ф. Мадхавы-Лейбница -  51 число пи = 3.1611986130e+00
# номер итерации ф. Валлиса -  51 число пи = 3.1120960900e+00
# номер итерации ф. Мадхавы-Лейбница -  52 число пи = 3.1223636615e+00
# номер итерации ф. Валлиса -  52 число пи = 3.1708148842e+00
# номер итерации ф. Мадхавы-Лейбница -  53 число пи = 3.1604588996e+00
# номер итерации ф. Валлиса -  53 число пи = 3.1131637045e+00
# номер итерации ф. Мадхавы-Лейбница -  54 число пи = 3.1230757221e+00
# номер итерации ф. Валлиса -  54 число пи = 3.1697666809e+00
# номер итерации ф. Мадхавы-Лейбница -  55 число пи = 3.1597729698e+00
# номер итерации ф. Валлиса -  55 число пи = 3.1141567391e+00
# номер итерации ф. Мадхавы-Лейбница -  56 число пи = 3.1237369337e+00
# номер итерации ф. Валлиса -  56 число пи = 3.1687910679e+00
# номер итерации ф. Мадхавы-Лейбница -  57 число пи = 3.1591351638e+00
# номер итерации ф. Валлиса -  57 число пи = 3.1150827447e+00
# номер итерации ф. Мадхавы-Лейбница -  58 число пи = 3.1243525551e+00
# номер итерации ф. Валлиса -  58 число пи = 3.1678807573e+00
# номер итерации ф. Мадхавы-Лейбница -  59 число пи = 3.1585405893e+00
# номер итерации ф. Валлиса -  59 число пи = 3.1159482859e+00
# номер итерации ф. Мадхавы-Лейбница -  60 число пи = 3.1249271439e+00
# номер итерации ф. Валлиса -  60 число пи = 3.1670294053e+00
# номер итерации ф. Мадхавы-Лейбница -  61 число пи = 3.1579849952e+00
# номер итерации ф. Валлиса -  61 число пи = 3.1167590973e+00
# номер итерации ф. Мадхавы-Лейбница -  62 число пи = 3.1254646700e+00
# номер итерации ф. Валлиса -  62 число пи = 3.1662314639e+00
# номер итерации ф. Мадхавы-Лейбница -  63 число пи = 3.1574646700e+00
# номер итерации ф. Валлиса -  63 число пи = 3.1175202106e+00
# номер итерации ф. Мадхавы-Лейбница -  64 число пи = 3.1259686070e+00
# номер итерации ф. Валлиса -  64 число пи = 3.1654820600e+00
# номер итерации ф. Мадхавы-Лейбница -  65 число пи = 3.1569763589e+00
# номер итерации ф. Валлиса -  65 число пи = 3.1182360591e+00
# номер итерации ф. Мадхавы-Лейбница -  66 число пи = 3.1264420078e+00
# номер итерации ф. Валлиса -  66 число пи = 3.1647768958e+00
# номер итерации ф. Мадхавы-Лейбница -  67 число пи = 3.1565171957e+00
# номер итерации ф. Валлиса -  67 число пи = 3.1189105640e+00
# номер итерации ф. Мадхавы-Лейбница -  68 число пи = 3.1268875661e+00
# номер итерации ф. Валлиса -  68 число пи = 3.1641121664e+00
# номер итерации ф. Мадхавы-Лейбница -  69 число пи = 3.1560846464e+00
# номер итерации ф. Валлиса -  69 число пи = 3.1195472063e+00
# номер итерации ф. Мадхавы-Лейбница -  70 число пи = 3.1273076680e+00
# номер итерации ф. Валлиса -  70 число пи = 3.1634844909e+00
# номер итерации ф. Мадхавы-Лейбница -  71 число пи = 3.1556764623e+00
# номер итерации ф. Валлиса -  71 число пи = 3.1201490869e+00
# номер итерации ф. Мадхавы-Лейбница -  72 число пи = 3.1277044343e+00
# номер итерации ф. Валлиса -  72 число пи = 3.1628908552e+00
# номер итерации ф. Мадхавы-Лейбница -  73 число пи = 3.1552906412e+00
# номер итерации ф. Валлиса -  73 число пи = 3.1207189772e+00
# номер итерации ф. Мадхавы-Лейбница -  74 число пи = 3.1280797569e+00
# номер итерации ф. Валлиса -  74 число пи = 3.1623285635e+00
# номер итерации ф. Мадхавы-Лейбница -  75 число пи = 3.1549253945e+00
# номер итерации ф. Валлиса -  75 число пи = 3.1212593614e+00
# номер итерации ф. Мадхавы-Лейбница -  76 число пи = 3.1284353282e+00
# номер итерации ф. Валлиса -  76 число пи = 3.1617951973e+00
# номер итерации ф. Мадхавы-Лейбница -  77 число пи = 3.1545791191e+00
# номер итерации ф. Валлиса -  77 число пи = 3.1217724732e+00
# номер итерации ф. Мадхавы-Лейбница -  78 число пи = 3.1287726675e+00
# номер итерации ф. Валлиса -  78 число пи = 3.1612885805e+00
# номер итерации ф. Мадхавы-Лейбница -  79 число пи = 3.1542503745e+00
# номер итерации ф. Валлиса -  79 число пи = 3.1222603264e+00
# номер итерации ф. Мадхавы-Лейбница -  80 число пи = 3.1290931418e+00
# номер итерации ф. Валлиса -  80 число пи = 3.1608067502e+00
# номер итерации ф. Мадхавы-Лейбница -  81 число пи = 3.1539378623e+00
# номер итерации ф. Валлиса -  81 число пи = 3.1227247412e+00
# номер итерации ф. Мадхавы-Лейбница -  82 число пи = 3.1293979850e+00
# номер итерации ф. Валлиса -  82 число пи = 3.1603479308e+00
# номер итерации ф. Мадхавы-Лейбница -  83 число пи = 3.1536404092e+00
# номер итерации ф. Валлиса -  83 число пи = 3.1231673669e+00
# номер итерации ф. Мадхавы-Лейбница -  84 число пи = 3.1296883134e+00
# номер итерации ф. Валлиса -  84 число пи = 3.1599105124e+00
# номер итерации ф. Мадхавы-Лейбница -  85 число пи = 3.1533569525e+00
# номер итерации ф. Валлиса -  85 число пи = 3.1235897019e+00
# номер итерации ф. Мадхавы-Лейбница -  86 число пи = 3.1299651396e+00
# номер итерации ф. Валлиса -  86 число пи = 3.1594930318e+00
# номер итерации ф. Мадхавы-Лейбница -  87 число пи = 3.1530865269e+00
# номер итерации ф. Валлиса -  87 число пи = 3.1239931101e+00
# номер итерации ф. Мадхавы-Лейбница -  88 число пи = 3.1302293840e+00
# номер итерации ф. Валлиса -  88 число пи = 3.1590941563e+00
# номер итерации ф. Мадхавы-Лейбница -  89 число пи = 3.1528282541e+00
# номер итерации ф. Валлиса -  89 число пи = 3.1243788359e+00
# номер итерации ф. Мадхавы-Лейбница -  90 число пи = 3.1304818854e+00
# номер итерации ф. Валлиса -  90 число пи = 3.1587126693e+00
# номер итерации ф. Мадхавы-Лейбница -  91 число пи = 3.1525813329e+00
# номер итерации ф. Валлиса -  91 число пи = 3.1247480169e+00
# номер итерации ф. Мадхавы-Лейбница -  92 число пи = 3.1307234094e+00
# номер итерации ф. Валлиса -  92 число пи = 3.1583474580e+00
# номер итерации ф. Мадхавы-Лейбница -  93 число пи = 3.1523450310e+00
# номер итерации ф. Валлиса -  93 число пи = 3.1251016952e+00
# номер итерации ф. Мадхавы-Лейбница -  94 число пи = 3.1309546567e+00
# номер итерации ф. Валлиса -  94 число пи = 3.1579975026e+00
# номер итерации ф. Мадхавы-Лейбница -  95 число пи = 3.1521186778e+00
# номер итерации ф. Валлиса -  95 число пи = 3.1254408273e+00
# номер итерации ф. Мадхавы-Лейбница -  96 число пи = 3.1311762695e+00
# номер итерации ф. Валлиса -  96 число пи = 3.1576618667e+00
# номер итерации ф. Мадхавы-Лейбница -  97 число пи = 3.1519016581e+00
# номер итерации ф. Валлиса -  97 число пи = 3.1257662923e+00
# номер итерации ф. Мадхавы-Лейбница -  98 число пи = 3.1313888375e+00
# номер итерации ф. Валлиса -  98 число пи = 3.1573396892e+00
# номер итерации ф. Мадхавы-Лейбница -  99 число пи = 3.1516934061e+00
# номер итерации ф. Валлиса -  99 число пи = 3.1260789002e+00
# номер итерации ф. Мадхавы-Лейбница -  100 число пи = 3.1315929036e+00
# номер итерации ф. Валлиса -  100 число пи = 3.1570301765e+00
# номер итерации ф. Мадхавы-Лейбница -  101 число пи = 3.1514934011e+00
# номер итерации ф. Валлиса -  101 число пи = 3.1263793980e+00
# номер итерации ф. Мадхавы-Лейбница -  102 число пи = 3.1317889676e+00
# номер итерации ф. Валлиса -  102 число пи = 3.1567325961e+00
# номер итерации ф. Мадхавы-Лейбница -  103 число пи = 3.1513011627e+00
# номер итерации ф. Валлиса -  103 число пи = 3.1266684761e+00
# номер итерации ф. Мадхавы-Лейбница -  104 число пи = 3.1319774912e+00
# номер итерации ф. Валлиса -  104 число пи = 3.1564462711e+00
# номер итерации ф. Мадхавы-Лейбница -  105 число пи = 3.1511162472e+00
# номер итерации ф. Валлиса -  105 число пи = 3.1269467733e+00
# номер итерации ф. Мадхавы-Лейбница -  106 число пи = 3.1321589012e+00
# номер итерации ф. Валлиса -  106 число пи = 3.1561705749e+00
# номер итерации ф. Мадхавы-Лейбница -  107 число пи = 3.1509382439e+00
# номер итерации ф. Валлиса -  107 число пи = 3.1272148815e+00
# номер итерации ф. Мадхавы-Лейбница -  108 число пи = 3.1323335928e+00
# номер итерации ф. Валлиса -  108 число пи = 3.1559049263e+00
# номер итерации ф. Мадхавы-Лейбница -  109 число пи = 3.1507667725e+00
# номер итерации ф. Валлиса -  109 число пи = 3.1274733504e+00
# номер итерации ф. Мадхавы-Лейбница -  110 число пи = 3.1325019323e+00
# номер итерации ф. Валлиса -  110 число пи = 3.1556487860e+00
# номер итерации ф. Мадхавы-Лейбница -  111 число пи = 3.1506014798e+00
# номер итерации ф. Валлиса -  111 число пи = 3.1277226906e+00
# номер итерации ф. Мадхавы-Лейбница -  112 число пи = 3.1326642601e+00
# номер итерации ф. Валлиса -  112 число пи = 3.1554016524e+00
# номер итерации ф. Мадхавы-Лейбница -  113 число пи = 3.1504420379e+00
# номер итерации ф. Валлиса -  113 число пи = 3.1279633772e+00
# номер итерации ф. Мадхавы-Лейбница -  114 число пи = 3.1328208925e+00
# номер итерации ф. Валлиса -  114 число пи = 3.1551630587e+00
# номер итерации ф. Мадхавы-Лейбница -  115 число пи = 3.1502881414e+00
# номер итерации ф. Валлиса -  115 число пи = 3.1281958531e+00
# номер итерации ф. Мадхавы-Лейбница -  116 число пи = 3.1329721241e+00
# номер итерации ф. Валлиса -  116 число пи = 3.1549325698e+00
# номер итерации ф. Мадхавы-Лейбница -  117 число пи = 3.1501395061e+00
# номер итерации ф. Валлиса -  117 число пи = 3.1284205314e+00
# номер итерации ф. Мадхавы-Лейбница -  118 число пи = 3.1331182295e+00
# номер итерации ф. Валлиса -  118 число пи = 3.1547097795e+00
# номер итерации ф. Мадхавы-Лейбница -  119 число пи = 3.1499958666e+00
# номер итерации ф. Валлиса -  119 число пи = 3.1286377979e+00
# номер итерации ф. Мадхавы-Лейбница -  120 число пи = 3.1332594649e+00
# номер итерации ф. Валлиса -  120 число пи = 3.1544943086e+00
# номер итерации ф. Мадхавы-Лейбница -  121 число пи = 3.1498569753e+00
# номер итерации ф. Валлиса -  121 число пи = 3.1288480134e+00
# номер итерации ф. Мадхавы-Лейбница -  122 число пи = 3.1333960699e+00
# номер итерации ф. Валлиса -  122 число пи = 3.1542858022e+00
# номер итерации ф. Мадхавы-Лейбница -  123 число пи = 3.1497226006e+00
# номер итерации ф. Валлиса -  123 число пи = 3.1290515157e+00
# номер итерации ф. Мадхавы-Лейбница -  124 число пи = 3.1335282686e+00
# номер итерации ф. Валлиса -  124 число пи = 3.1540839279e+00
# номер итерации ф. Мадхавы-Лейбница -  125 число пи = 3.1495925256e+00
# номер итерации ф. Валлиса -  125 число пи = 3.1292486213e+00
# номер итерации ф. Мадхавы-Лейбница -  126 число пи = 3.1336562706e+00
# номер итерации ф. Валлиса -  126 число пи = 3.1538883743e+00
# номер итерации ф. Мадхавы-Лейбница -  127 число пи = 3.1494665473e+00
# номер итерации ф. Валлиса -  127 число пи = 3.1294396272e+00
# номер итерации ф. Мадхавы-Лейбница -  128 число пи = 3.1337802728e+00
# номер итерации ф. Валлиса -  128 число пи = 3.1536988491e+00
# номер итерации ф. Мадхавы-Лейбница -  129 число пи = 3.1493444751e+00
# номер итерации ф. Валлиса -  129 число пи = 3.1296248121e+00
# номер итерации ф. Мадхавы-Лейбница -  130 число пи = 3.1339004597e+00
# номер итерации ф. Валлиса -  130 число пи = 3.1535150778e+00
# номер итерации ф. Мадхавы-Лейбница -  131 число пи = 3.1492261302e+00
# номер итерации ф. Валлиса -  131 число пи = 3.1298044381e+00
# номер итерации ф. Мадхавы-Лейбница -  132 число пи = 3.1340170047e+00
# номер итерации ф. Валлиса -  132 число пи = 3.1533368023e+00
# номер итерации ф. Мадхавы-Лейбница -  133 число пи = 3.1491113443e+00
# номер итерации ф. Валлиса -  133 число пи = 3.1299787519e+00
# номер итерации ф. Мадхавы-Лейбница -  134 число пи = 3.1341300709e+00
# номер итерации ф. Валлиса -  134 число пи = 3.1531637797e+00
# номер итерации ф. Мадхавы-Лейбница -  135 число пи = 3.1489999594e+00
# номер итерации ф. Валлиса -  135 число пи = 3.1301479857e+00
# номер итерации ф. Мадхавы-Лейбница -  136 число пи = 3.1342398118e+00
# номер итерации ф. Валлиса -  136 число пи = 3.1529957812e+00
# номер итерации ф. Мадхавы-Лейбница -  137 число пи = 3.1488918264e+00
# номер итерации ф. Валлиса -  137 число пи = 3.1303123584e+00
# номер итерации ф. Мадхавы-Лейбница -  138 число пи = 3.1343463719e+00
# номер итерации ф. Валлиса -  138 число пи = 3.1528325911e+00
# номер итерации ф. Мадхавы-Лейбница -  139 число пи = 3.1487868051e+00
# номер итерации ф. Валлиса -  139 число пи = 3.1304720763e+00
# номер итерации ф. Мадхавы-Лейбница -  140 число пи = 3.1344498875e+00
# номер итерации ф. Валлиса -  140 число пи = 3.1526740059e+00
# номер итерации ф. Мадхавы-Лейбница -  141 число пи = 3.1486847630e+00
# номер итерации ф. Валлиса -  141 число пи = 3.1306273346e+00
# номер итерации ф. Мадхавы-Лейбница -  142 число пи = 3.1345504874e+00
# номер итерации ф. Валлиса -  142 число пи = 3.1525198334e+00
# номер итерации ф. Мадхавы-Лейбница -  143 число пи = 3.1485855751e+00
# номер итерации ф. Валлиса -  143 число пи = 3.1307783173e+00
# номер итерации ф. Мадхавы-Лейбница -  144 число пи = 3.1346482929e+00
# номер итерации ф. Валлиса -  144 число пи = 3.1523698919e+00
# номер итерации ф. Мадхавы-Лейбница -  145 число пи = 3.1484891233e+00
# номер итерации ф. Валлиса -  145 число пи = 3.1309251988e+00
# номер итерации ф. Мадхавы-Лейбница -  146 число пи = 3.1347434188e+00
# номер итерации ф. Валлиса -  146 число пи = 3.1522240097e+00
# номер итерации ф. Мадхавы-Лейбница -  147 число пи = 3.1483952960e+00
# номер итерации ф. Валлиса -  147 число пи = 3.1310681438e+00
# номер итерации ф. Мадхавы-Лейбница -  148 число пи = 3.1348359739e+00
# номер итерации ф. Валлиса -  148 число пи = 3.1520820240e+00
# номер итерации ф. Мадхавы-Лейбница -  149 число пи = 3.1483039874e+00
# номер итерации ф. Валлиса -  149 число пи = 3.1312073086e+00
# номер итерации ф. Мадхавы-Лейбница -  150 число пи = 3.1349260610e+00
# номер итерации ф. Валлиса -  150 число пи = 3.1519437808e+00
# номер итерации ф. Мадхавы-Лейбница -  151 число пи = 3.1482150975e+00
# номер итерации ф. Валлиса -  151 число пи = 3.1313428411e+00
# номер итерации ф. Мадхавы-Лейбница -  152 число пи = 3.1350137774e+00
# номер итерации ф. Валлиса -  152 число пи = 3.1518091342e+00
# номер итерации ф. Мадхавы-Лейбница -  153 число пи = 3.1481285315e+00
# номер итерации ф. Валлиса -  153 число пи = 3.1314748817e+00
# номер итерации ф. Мадхавы-Лейбница -  154 число пи = 3.1350992155e+00
# номер итерации ф. Валлиса -  154 число пи = 3.1516779454e+00
# номер итерации ф. Мадхавы-Лейбница -  155 число пи = 3.1480441994e+00
# номер итерации ф. Валлиса -  155 число пи = 3.1316035636e+00
# номер итерации ф. Мадхавы-Лейбница -  156 число пи = 3.1351824630e+00
# номер итерации ф. Валлиса -  156 число пи = 3.1515500831e+00
# номер итерации ф. Мадхавы-Лейбница -  157 число пи = 3.1479620157e+00
# номер итерации ф. Валлиса -  157 число пи = 3.1317290134e+00
# номер итерации ф. Мадхавы-Лейбница -  158 число пи = 3.1352636030e+00
# номер итерации ф. Валлиса -  158 число пи = 3.1514254223e+00
# номер итерации ф. Мадхавы-Лейбница -  159 число пи = 3.1478818996e+00
# номер итерации ф. Валлиса -  159 число пи = 3.1318513514e+00
# номер итерации ф. Мадхавы-Лейбница -  160 число пи = 3.1353427146e+00
# номер итерации ф. Валлиса -  160 число пи = 3.1513038442e+00
# номер итерации ф. Мадхавы-Лейбница -  161 число пи = 3.1478037738e+00
# номер итерации ф. Валлиса -  161 число пи = 3.1319706918e+00
# номер итерации ф. Мадхавы-Лейбница -  162 число пи = 3.1354198729e+00
# номер итерации ф. Валлиса -  162 число пи = 3.1511852359e+00
# номер итерации ф. Мадхавы-Лейбница -  163 число пи = 3.1477275652e+00
# номер итерации ф. Валлиса -  163 число пи = 3.1320871436e+00
# номер итерации ф. Мадхавы-Лейбница -  164 число пи = 3.1354951493e+00
# номер итерации ф. Валлиса -  164 число пи = 3.1510694899e+00
# номер итерации ф. Мадхавы-Лейбница -  165 число пи = 3.1476532040e+00
# номер итерации ф. Валлиса -  165 число пи = 3.1322008103e+00
# номер итерации ф. Мадхавы-Лейбница -  166 число пи = 3.1355686119e+00
# номер итерации ф. Валлиса -  166 число пи = 3.1509565038e+00
# номер итерации ф. Мадхавы-Лейбница -  167 число пи = 3.1475806239e+00
# номер итерации ф. Валлиса -  167 число пи = 3.1323117908e+00
# номер итерации ф. Мадхавы-Лейбница -  168 число пи = 3.1356403254e+00
# номер итерации ф. Валлиса -  168 число пи = 3.1508461801e+00
# номер итерации ф. Мадхавы-Лейбница -  169 число пи = 3.1475097616e+00
# номер итерации ф. Валлиса -  169 число пи = 3.1324201790e+00
# номер итерации ф. Мадхавы-Лейбница -  170 число пи = 3.1357103515e+00
# номер итерации ф. Валлиса -  170 число пи = 3.1507384257e+00
# номер итерации ф. Мадхавы-Лейбница -  171 число пи = 3.1474405568e+00
# номер итерации ф. Валлиса -  171 число пи = 3.1325260648e+00
# номер итерации ф. Мадхавы-Лейбница -  172 число пи = 3.1357787492e+00
# номер итерации ф. Валлиса -  172 число пи = 3.1506331519e+00
# номер итерации ф. Мадхавы-Лейбница -  173 число пи = 3.1473729521e+00
# номер итерации ф. Валлиса -  173 число пи = 3.1326295339e+00
# номер итерации ф. Мадхавы-Лейбница -  174 число пи = 3.1358455746e+00
# номер итерации ф. Валлиса -  174 число пи = 3.1505302741e+00
# номер итерации ф. Мадхавы-Лейбница -  175 число пи = 3.1473068927e+00
# номер итерации ф. Валлиса -  175 число пи = 3.1327306680e+00
# номер итерации ф. Мадхавы-Лейбница -  176 число пи = 3.1359108813e+00
# номер итерации ф. Валлиса -  176 число пи = 3.1504297114e+00
# номер итерации ф. Мадхавы-Лейбница -  177 число пи = 3.1472423260e+00
# номер итерации ф. Валлиса -  177 число пи = 3.1328295454e+00
# номер итерации ф. Мадхавы-Лейбница -  178 число пи = 3.1359747204e+00
# номер итерации ф. Валлиса -  178 число пи = 3.1503313864e+00
# номер итерации ф. Мадхавы-Лейбница -  179 число пи = 3.1471792022e+00
# номер итерации ф. Валлиса -  179 число пи = 3.1329262406e+00
# номер итерации ф. Мадхавы-Лейбница -  180 число пи = 3.1360371409e+00
# номер итерации ф. Валлиса -  180 число пи = 3.1502352254e+00
# номер итерации ф. Мадхавы-Лейбница -  181 число пи = 3.1471174733e+00
# номер итерации ф. Валлиса -  181 число пи = 3.1330208252e+00
# номер итерации ф. Мадхавы-Лейбница -  182 число пи = 3.1360981896e+00
# номер итерации ф. Валлиса -  182 число пи = 3.1501411576e+00
# номер итерации ф. Мадхавы-Лейбница -  183 число пи = 3.1470570937e+00
# номер итерации ф. Валлиса -  183 число пи = 3.1331133676e+00
# номер итерации ф. Мадхавы-Лейбница -  184 число пи = 3.1361579111e+00
# номер итерации ф. Валлиса -  184 число пи = 3.1500491155e+00
# номер итерации ф. Мадхавы-Лейбница -  185 число пи = 3.1469980195e+00
# номер итерации ф. Валлиса -  185 число пи = 3.1332039331e+00
# номер итерации ф. Мадхавы-Лейбница -  186 число пи = 3.1362163484e+00
# номер итерации ф. Валлиса -  186 число пи = 3.1499590343e+00
# номер итерации ф. Мадхавы-Лейбница -  187 число пи = 3.1469402089e+00
# номер итерации ф. Валлиса -  187 число пи = 3.1332925844e+00
# номер итерации ф. Мадхавы-Лейбница -  188 число пи = 3.1362735423e+00
# номер итерации ф. Валлиса -  188 число пи = 3.1498708520e+00
# номер итерации ф. Мадхавы-Лейбница -  189 число пи = 3.1468836219e+00
# номер итерации ф. Валлиса -  189 число пи = 3.1333793816e+00
# номер итерации ф. Мадхавы-Лейбница -  190 число пи = 3.1363295321e+00
# номер итерации ф. Валлиса -  190 число пи = 3.1497845093e+00
# номер итерации ф. Мадхавы-Лейбница -  191 число пи = 3.1468282198e+00
# номер итерации ф. Валлиса -  191 число пи = 3.1334643823e+00
# номер итерации ф. Мадхавы-Лейбница -  192 число пи = 3.1363843556e+00
# номер итерации ф. Валлиса -  192 число пи = 3.1496999490e+00
# номер итерации ф. Мадхавы-Лейбница -  193 число пи = 3.1467739660e+00
# номер итерации ф. Валлиса -  193 число пи = 3.1335476416e+00
# номер итерации ф. Мадхавы-Лейбница -  194 число пи = 3.1364380487e+00
# номер итерации ф. Валлиса -  194 число пи = 3.1496171167e+00
# номер итерации ф. Мадхавы-Лейбница -  195 число пи = 3.1467208250e+00
# номер итерации ф. Валлиса -  195 число пи = 3.1336292125e+00
# номер итерации ф. Мадхавы-Лейбница -  196 число пи = 3.1364906460e+00
# номер итерации ф. Валлиса -  196 число пи = 3.1495359598e+00
# номер итерации ф. Мадхавы-Лейбница -  197 число пи = 3.1466687630e+00
# номер итерации ф. Валлиса -  197 число пи = 3.1337091459e+00
# номер итерации ф. Мадхавы-Лейбница -  198 число пи = 3.1365421807e+00
# номер итерации ф. Валлиса -  198 число пи = 3.1494564281e+00
# номер итерации ф. Мадхавы-Лейбница -  199 число пи = 3.1466177475e+00
# номер итерации ф. Валлиса -  199 число пи = 3.1337874906e+00
# номер итерации ф. Мадхавы-Лейбница -  200 число пи = 3.1365926848e+00
# номер итерации ф. Валлиса -  200 число пи = 3.1493784732e+00
# номер итерации ф. Мадхавы-Лейбница -  201 число пи = 3.1465677472e+00
# номер итерации ф. Валлиса -  201 число пи = 3.1338642935e+00
# номер итерации ф. Мадхавы-Лейбница -  202 число пи = 3.1366421889e+00
# номер итерации ф. Валлиса -  202 число пи = 3.1493020486e+00
# номер итерации ф. Мадхавы-Лейбница -  203 число пи = 3.1465187321e+00
# номер итерации ф. Валлиса -  203 число пи = 3.1339395996e+00
# номер итерации ф. Мадхавы-Лейбница -  204 число пи = 3.1366907223e+00
# номер итерации ф. Валлиса -  204 число пи = 3.1492271099e+00
# номер итерации ф. Мадхавы-Лейбница -  205 число пи = 3.1464706734e+00
# номер итерации ф. Валлиса -  205 число пи = 3.1340134523e+00
# номер итерации ф. Мадхавы-Лейбница -  206 число пи = 3.1367383133e+00
# номер итерации ф. Валлиса -  206 число пи = 3.1491536139e+00
# номер итерации ф. Мадхавы-Лейбница -  207 число пи = 3.1464235433e+00
# номер итерации ф. Валлиса -  207 число пи = 3.1340858933e+00
# номер итерации ф. Мадхавы-Лейбница -  208 число пи = 3.1367849891e+00
# номер итерации ф. Валлиса -  208 число пи = 3.1490815196e+00
# номер итерации ф. Мадхавы-Лейбница -  209 число пи = 3.1463773152e+00
# номер итерации ф. Валлиса -  209 число пи = 3.1341569626e+00
# номер итерации ф. Мадхавы-Лейбница -  210 число пи = 3.1368307758e+00
# номер итерации ф. Валлиса -  210 число пи = 3.1490107871e+00
# номер итерации ф. Мадхавы-Лейбница -  211 число пи = 3.1463319635e+00
# номер итерации ф. Валлиса -  211 число пи = 3.1342266989e+00
# номер итерации ф. Мадхавы-Лейбница -  212 число пи = 3.1368756987e+00
# номер итерации ф. Валлиса -  212 число пи = 3.1489413782e+00
# номер итерации ф. Мадхавы-Лейбница -  213 число пи = 3.1462874634e+00
# номер итерации ф. Валлиса -  213 число пи = 3.1342951392e+00
# номер итерации ф. Мадхавы-Лейбница -  214 число пи = 3.1369197819e+00
# номер итерации ф. Валлиса -  214 число пи = 3.1488732562e+00
# номер итерации ф. Мадхавы-Лейбница -  215 число пи = 3.1462437912e+00
# номер итерации ф. Валлиса -  215 число пи = 3.1343623195e+00
# номер итерации ф. Мадхавы-Лейбница -  216 число пи = 3.1369630488e+00
# номер итерации ф. Валлиса -  216 число пи = 3.1488063855e+00
# номер итерации ф. Мадхавы-Лейбница -  217 число пи = 3.1462009241e+00
# номер итерации ф. Валлиса -  217 число пи = 3.1344282741e+00
# номер итерации ф. Мадхавы-Лейбница -  218 число пи = 3.1370055218e+00
# номер итерации ф. Валлиса -  218 число пи = 3.1487407320e+00
# номер итерации ф. Мадхавы-Лейбница -  219 число пи = 3.1461588398e+00
# номер итерации ф. Валлиса -  219 число пи = 3.1344930364e+00
# номер итерации ф. Мадхавы-Лейбница -  220 число пи = 3.1370472225e+00
# номер итерации ф. Валлиса -  220 число пи = 3.1486762628e+00
# номер итерации ф. Мадхавы-Лейбница -  221 число пи = 3.1461175173e+00
# номер итерации ф. Валлиса -  221 число пи = 3.1345566383e+00
# номер итерации ф. Мадхавы-Лейбница -  222 число пи = 3.1370881719e+00
# номер итерации ф. Валлиса -  222 число пи = 3.1486129461e+00
# номер итерации ф. Мадхавы-Лейбница -  223 число пи = 3.1460769360e+00
# номер итерации ф. Валлиса -  223 число пи = 3.1346191108e+00
# номер итерации ф. Мадхавы-Лейбница -  224 число пи = 3.1371283901e+00
# номер итерации ф. Валлиса -  224 число пи = 3.1485507513e+00
# номер итерации ф. Мадхавы-Лейбница -  225 число пи = 3.1460370761e+00
# номер итерации ф. Валлиса -  225 число пи = 3.1346804837e+00
# номер итерации ф. Мадхавы-Лейбница -  226 число пи = 3.1371678965e+00
# номер итерации ф. Валлиса -  226 число пи = 3.1484896488e+00
# номер итерации ф. Мадхавы-Лейбница -  227 число пи = 3.1459979186e+00
# номер итерации ф. Валлиса -  227 число пи = 3.1347407857e+00
# номер итерации ф. Мадхавы-Лейбница -  228 число пи = 3.1372067098e+00
# номер итерации ф. Валлиса -  228 число пи = 3.1484296101e+00
# номер итерации ф. Мадхавы-Лейбница -  229 число пи = 3.1459594450e+00
# номер итерации ф. Валлиса -  229 число пи = 3.1348000447e+00
# номер итерации ф. Мадхавы-Лейбница -  230 число пи = 3.1372448480e+00
# номер итерации ф. Валлиса -  230 число пи = 3.1483706076e+00
# номер итерации ф. Мадхавы-Лейбница -  231 число пи = 3.1459216376e+00
# номер итерации ф. Валлиса -  231 число пи = 3.1348582874e+00
# номер итерации ф. Мадхавы-Лейбница -  232 число пи = 3.1372823288e+00
# номер итерации ф. Валлиса -  232 число пи = 3.1483126148e+00
# номер итерации ф. Мадхавы-Лейбница -  233 число пи = 3.1458844793e+00
# номер итерации ф. Валлиса -  233 число пи = 3.1349155399e+00
# номер итерации ф. Мадхавы-Лейбница -  234 число пи = 3.1373191688e+00
# номер итерации ф. Валлиса -  234 число пи = 3.1482556060e+00
# номер итерации ф. Мадхавы-Лейбница -  235 число пи = 3.1458479535e+00
# номер итерации ф. Валлиса -  235 число пи = 3.1349718271e+00
# номер итерации ф. Мадхавы-Лейбница -  236 число пи = 3.1373553845e+00
# номер итерации ф. Валлиса -  236 число пи = 3.1481995563e+00
# номер итерации ф. Мадхавы-Лейбница -  237 число пи = 3.1458120441e+00
# номер итерации ф. Валлиса -  237 число пи = 3.1350271732e+00
# номер итерации ф. Мадхавы-Лейбница -  238 число пи = 3.1373909915e+00
# номер итерации ф. Валлиса -  238 число пи = 3.1481444417e+00
# номер итерации ф. Мадхавы-Лейбница -  239 число пи = 3.1457767357e+00
# номер итерации ф. Валлиса -  239 число пи = 3.1350816017e+00
# номер итерации ф. Мадхавы-Лейбница -  240 число пи = 3.1374260050e+00
# номер итерации ф. Валлиса -  240 число пи = 3.1480902391e+00
# номер итерации ф. Мадхавы-Лейбница -  241 число пи = 3.1457420133e+00
# номер итерации ф. Валлиса -  241 число пи = 3.1351351352e+00
# номер итерации ф. Мадхавы-Лейбница -  242 число пи = 3.1374604398e+00
# номер итерации ф. Валлиса -  242 число пи = 3.1480369259e+00
# номер итерации ф. Мадхавы-Лейбница -  243 число пи = 3.1457078625e+00
# номер итерации ф. Валлиса -  243 число пи = 3.1351877956e+00
# номер итерации ф. Мадхавы-Лейбница -  244 число пи = 3.1374943101e+00
# номер итерации ф. Валлиса -  244 число пи = 3.1479844805e+00
# номер итерации ф. Мадхавы-Лейбница -  245 число пи = 3.1456742692e+00
# номер итерации ф. Валлиса -  245 число пи = 3.1352396040e+00
# номер итерации ф. Мадхавы-Лейбница -  246 число пи = 3.1375276297e+00
# номер итерации ф. Валлиса -  246 число пи = 3.1479328818e+00
# номер итерации ф. Мадхавы-Лейбница -  247 число пи = 3.1456412200e+00
# номер итерации ф. Валлиса -  247 число пи = 3.1352905810e+00
# номер итерации ф. Мадхавы-Лейбница -  248 число пи = 3.1375604119e+00
# номер итерации ф. Валлиса -  248 число пи = 3.1478821095e+00
# номер итерации ф. Мадхавы-Лейбница -  249 число пи = 3.1456087017e+00
# номер итерации ф. Валлиса -  249 число пи = 3.1353407465e+00
# номер итерации ф. Мадхавы-Лейбница -  250 число пи = 3.1375926696e+00
# номер итерации ф. Валлиса -  250 число пи = 3.1478321439e+00
# номер итерации ф. Мадхавы-Лейбница -  251 число пи = 3.1455767015e+00
# номер итерации ф. Валлиса -  251 число пи = 3.1353901196e+00
# номер итерации ф. Мадхавы-Лейбница -  252 число пи = 3.1376244152e+00
# номер итерации ф. Валлиса -  252 число пи = 3.1477829659e+00
# номер итерации ф. Мадхавы-Лейбница -  253 число пи = 3.1455452073e+00
# номер итерации ф. Валлиса -  253 число пи = 3.1354387190e+00
# номер итерации ф. Мадхавы-Лейбница -  254 число пи = 3.1376556610e+00
# номер итерации ф. Валлиса -  254 число пи = 3.1477345571e+00
# номер итерации ф. Мадхавы-Лейбница -  255 число пи = 3.1455142071e+00
# номер итерации ф. Валлиса -  255 число пи = 3.1354865627e+00
# номер итерации ф. Мадхавы-Лейбница -  256 число пи = 3.1376864185e+00
# номер итерации ф. Валлиса -  256 число пи = 3.1476868996e+00
# номер итерации ф. Мадхавы-Лейбница -  257 число пи = 3.1454836894e+00
# номер итерации ф. Валлиса -  257 число пи = 3.1355336683e+00
# номер итерации ф. Мадхавы-Лейбница -  258 число пи = 3.1377166992e+00
# номер итерации ф. Валлиса -  258 число пи = 3.1476399759e+00
# номер итерации ф. Мадхавы-Лейбница -  259 число пи = 3.1454536431e+00
# номер итерации ф. Валлиса -  259 число пи = 3.1355800526e+00
# номер итерации ф. Мадхавы-Лейбница -  260 число пи = 3.1377465140e+00
# номер итерации ф. Валлиса -  260 число пи = 3.1475937693e+00
# номер итерации ф. Мадхавы-Лейбница -  261 число пи = 3.1454240572e+00
# номер итерации ф. Валлиса -  261 число пи = 3.1356257321e+00
# номер итерации ф. Мадхавы-Лейбница -  262 число пи = 3.1377758736e+00
# номер итерации ф. Валлиса -  262 число пи = 3.1475482634e+00
# номер итерации ф. Мадхавы-Лейбница -  263 число пи = 3.1453949212e+00
# номер итерации ф. Валлиса -  263 число пи = 3.1356707228e+00
# номер итерации ф. Мадхавы-Лейбница -  264 число пи = 3.1378047884e+00
# номер итерации ф. Валлиса -  264 число пи = 3.1475034425e+00
# номер итерации ф. Мадхавы-Лейбница -  265 число пи = 3.1453662251e+00
# номер итерации ф. Валлиса -  265 число пи = 3.1357150401e+00
# номер итерации ф. Мадхавы-Лейбница -  266 число пи = 3.1378332684e+00
# номер итерации ф. Валлиса -  266 число пи = 3.1474592912e+00
# номер итерации ф. Мадхавы-Лейбница -  267 число пи = 3.1453379588e+00
# номер итерации ф. Валлиса -  267 число пи = 3.1357586990e+00
# номер итерации ф. Мадхавы-Лейбница -  268 число пи = 3.1378613233e+00
# номер итерации ф. Валлиса -  268 число пи = 3.1474157946e+00
# номер итерации ф. Мадхавы-Лейбница -  269 число пи = 3.1453101129e+00
# номер итерации ф. Валлиса -  269 число пи = 3.1358017142e+00
# номер итерации ф. Мадхавы-Лейбница -  270 число пи = 3.1378889626e+00
# номер итерации ф. Валлиса -  270 число пи = 3.1473729382e+00
# номер итерации ф. Мадхавы-Лейбница -  271 число пи = 3.1452826779e+00
# номер итерации ф. Валлиса -  271 число пи = 3.1358440996e+00
# номер итерации ф. Мадхавы-Лейбница -  272 число пи = 3.1379161954e+00
# номер итерации ф. Валлиса -  272 число пи = 3.1473307080e+00
# номер итерации ф. Мадхавы-Лейбница -  273 число пи = 3.1452556450e+00
# номер итерации ф. Валлиса -  273 число пи = 3.1358858691e+00
# номер итерации ф. Мадхавы-Лейбница -  274 число пи = 3.1379430307e+00
# номер итерации ф. Валлиса -  274 число пи = 3.1472890904e+00
# номер итерации ф. Мадхавы-Лейбница -  275 число пи = 3.1452290052e+00
# номер итерации ф. Валлиса -  275 число пи = 3.1359270359e+00
# номер итерации ф. Мадхавы-Лейбница -  276 число пи = 3.1379694771e+00
# номер итерации ф. Валлиса -  276 число пи = 3.1472480722e+00
# номер итерации ф. Мадхавы-Лейбница -  277 число пи = 3.1452027501e+00
# номер итерации ф. Валлиса -  277 число пи = 3.1359676131e+00
# номер итерации ф. Мадхавы-Лейбница -  278 число пи = 3.1379955429e+00
# номер итерации ф. Валлиса -  278 число пи = 3.1472076404e+00
# номер итерации ф. Мадхавы-Лейбница -  279 число пи = 3.1451768715e+00
# номер итерации ф. Валлиса -  279 число пи = 3.1360076132e+00
# номер итерации ф. Мадхавы-Лейбница -  280 число пи = 3.1380212364e+00
# номер итерации ф. Валлиса -  280 число пи = 3.1471677827e+00
# номер итерации ф. Мадхавы-Лейбница -  281 число пи = 3.1451513612e+00
# номер итерации ф. Валлиса -  281 число пи = 3.1360470485e+00
# номер итерации ф. Мадхавы-Лейбница -  282 число пи = 3.1380465654e+00
# номер итерации ф. Валлиса -  282 число пи = 3.1471284868e+00
# номер итерации ф. Мадхавы-Лейбница -  283 число пи = 3.1451262115e+00
# номер итерации ф. Валлиса -  283 число пи = 3.1360859307e+00
# номер итерации ф. Мадхавы-Лейбница -  284 число пи = 3.1380715377e+00
# номер итерации ф. Валлиса -  284 число пи = 3.1470897410e+00
# номер итерации ф. Мадхавы-Лейбница -  285 число пи = 3.1451014147e+00
# номер итерации ф. Валлиса -  285 число пи = 3.1361242715e+00
# номер итерации ф. Мадхавы-Лейбница -  286 число пи = 3.1380961608e+00
# номер итерации ф. Валлиса -  286 число пи = 3.1470515338e+00
# номер итерации ф. Мадхавы-Лейбница -  287 число пи = 3.1450769636e+00
# номер итерации ф. Валлиса -  287 число пи = 3.1361620821e+00
# номер итерации ф. Мадхавы-Лейбница -  288 число пи = 3.1381204418e+00
# номер итерации ф. Валлиса -  288 число пи = 3.1470138540e+00
# номер итерации ф. Мадхавы-Лейбница -  289 число пи = 3.1450528508e+00
# номер итерации ф. Валлиса -  289 число пи = 3.1361993734e+00
# номер итерации ф. Мадхавы-Лейбница -  290 число пи = 3.1381443880e+00
# номер итерации ф. Валлиса -  290 число пи = 3.1469766908e+00
# номер итерации ф. Мадхавы-Лейбница -  291 число пи = 3.1450290696e+00
# номер итерации ф. Валлиса -  291 число пи = 3.1362361561e+00
# номер итерации ф. Мадхавы-Лейбница -  292 число пи = 3.1381680061e+00
# номер итерации ф. Валлиса -  292 число пи = 3.1469400337e+00
# номер итерации ф. Мадхавы-Лейбница -  293 число пи = 3.1450056129e+00
# номер итерации ф. Валлиса -  293 число пи = 3.1362724404e+00
# номер итерации ф. Мадхавы-Лейбница -  294 число пи = 3.1381913029e+00
# номер итерации ф. Валлиса -  294 число пи = 3.1469038724e+00
# номер итерации ф. Мадхавы-Лейбница -  295 число пи = 3.1449824744e+00
# номер итерации ф. Валлиса -  295 число пи = 3.1363082365e+00
# номер итерации ф. Мадхавы-Лейбница -  296 число пи = 3.1382142849e+00
# номер итерации ф. Валлиса -  296 число пи = 3.1468681969e+00
# номер итерации ф. Мадхавы-Лейбница -  297 число пи = 3.1449596474e+00
# номер итерации ф. Валлиса -  297 число пи = 3.1363435541e+00
# номер итерации ф. Мадхавы-Лейбница -  298 число пи = 3.1382369583e+00
# номер итерации ф. Валлиса -  298 число пи = 3.1468329974e+00
# номер итерации ф. Мадхавы-Лейбница -  299 число пи = 3.1449371258e+00
# номер итерации ф. Валлиса -  299 число пи = 3.1363784027e+00
# номер итерации ф. Мадхавы-Лейбница -  300 число пи = 3.1382593295e+00
# номер итерации ф. Валлиса -  300 число пи = 3.1467982645e+00
# номер итерации ф. Мадхавы-Лейбница -  301 число пи = 3.1449149036e+00
# номер итерации ф. Валлиса -  301 число пи = 3.1364127917e+00
# номер итерации ф. Мадхавы-Лейбница -  302 число пи = 3.1382814044e+00
# номер итерации ф. Валлиса -  302 число пи = 3.1467639890e+00
# номер итерации ф. Мадхавы-Лейбница -  303 число пи = 3.1448929746e+00
# номер итерации ф. Валлиса -  303 число пи = 3.1364467300e+00
# номер итерации ф. Мадхавы-Лейбница -  304 число пи = 3.1383031888e+00
# номер итерации ф. Валлиса -  304 число пи = 3.1467301619e+00
# номер итерации ф. Мадхавы-Лейбница -  305 число пи = 3.1448713333e+00
# номер итерации ф. Валлиса -  305 число пи = 3.1364802266e+00
# номер итерации ф. Мадхавы-Лейбница -  306 число пи = 3.1383246885e+00
# номер итерации ф. Валлиса -  306 число пи = 3.1466967745e+00
# номер итерации ф. Мадхавы-Лейбница -  307 число пи = 3.1448499739e+00
# номер итерации ф. Валлиса -  307 число пи = 3.1365132898e+00
# номер итерации ф. Мадхавы-Лейбница -  308 число пи = 3.1383459089e+00
# номер итерации ф. Валлиса -  308 число пи = 3.1466638183e+00
# номер итерации ф. Мадхавы-Лейбница -  309 число пи = 3.1448288911e+00
# номер итерации ф. Валлиса -  309 число пи = 3.1365459282e+00
# номер итерации ф. Мадхавы-Лейбница -  310 число пи = 3.1383668555e+00
# номер итерации ф. Валлиса -  310 число пи = 3.1466312849e+00
# номер итерации ф. Мадхавы-Лейбница -  311 число пи = 3.1448080794e+00
# номер итерации ф. Валлиса -  311 число пи = 3.1365781498e+00
# номер итерации ф. Мадхавы-Лейбница -  312 число пи = 3.1383875336e+00
# номер итерации ф. Валлиса -  312 число пи = 3.1465991662e+00
# номер итерации ф. Мадхавы-Лейбница -  313 число пи = 3.1447875336e+00
# номер итерации ф. Валлиса -  313 число пи = 3.1366099625e+00
# номер итерации ф. Мадхавы-Лейбница -  314 число пи = 3.1384079483e+00
# номер итерации ф. Валлиса -  314 число пи = 3.1465674545e+00
# номер итерации ф. Мадхавы-Лейбница -  315 число пи = 3.1447672488e+00
# номер итерации ф. Валлиса -  315 число пи = 3.1366413742e+00
# номер итерации ф. Мадхавы-Лейбница -  316 число пи = 3.1384281046e+00
# номер итерации ф. Валлиса -  316 число пи = 3.1465361419e+00
# номер итерации ф. Мадхавы-Лейбница -  317 число пи = 3.1447472199e+00
# номер итерации ф. Валлиса -  317 число пи = 3.1366723922e+00
# номер итерации ф. Мадхавы-Лейбница -  318 число пи = 3.1384480073e+00
# номер итерации ф. Валлиса -  318 число пи = 3.1465052211e+00
# номер итерации ф. Мадхавы-Лейбница -  319 число пи = 3.1447274421e+00
# номер итерации ф. Валлиса -  319 число пи = 3.1367030241e+00
# номер итерации ф. Мадхавы-Лейбница -  320 число пи = 3.1384676612e+00
# номер итерации ф. Валлиса -  320 число пи = 3.1464746846e+00
# номер итерации ф. Мадхавы-Лейбница -  321 число пи = 3.1447079108e+00
# номер итерации ф. Валлиса -  321 число пи = 3.1367332769e+00
# номер итерации ф. Мадхавы-Лейбница -  322 число пи = 3.1384870710e+00
# номер итерации ф. Валлиса -  322 число пи = 3.1464445255e+00
# номер итерации ф. Мадхавы-Лейбница -  323 число пи = 3.1446886214e+00
# номер итерации ф. Валлиса -  323 число пи = 3.1367631577e+00
# номер итерации ф. Мадхавы-Лейбница -  324 число пи = 3.1385062412e+00
# номер итерации ф. Валлиса -  324 число пи = 3.1464147366e+00
# номер итерации ф. Мадхавы-Лейбница -  325 число пи = 3.1446695694e+00
# номер итерации ф. Валлиса -  325 число пи = 3.1367926732e+00
# номер итерации ф. Мадхавы-Лейбница -  326 число пи = 3.1385251761e+00
# номер итерации ф. Валлиса -  326 число пи = 3.1463853114e+00
# номер итерации ф. Мадхавы-Лейбница -  327 число пи = 3.1446507504e+00
# номер итерации ф. Валлиса -  327 число пи = 3.1368218302e+00
# номер итерации ф. Мадхавы-Лейбница -  328 число пи = 3.1385438802e+00
# номер итерации ф. Валлиса -  328 число пи = 3.1463562430e+00
# номер итерации ф. Мадхавы-Лейбница -  329 число пи = 3.1446321602e+00
# номер итерации ф. Валлиса -  329 число пи = 3.1368506351e+00
# номер итерации ф. Мадхавы-Лейбница -  330 число пи = 3.1385623575e+00
# номер итерации ф. Валлиса -  330 число пи = 3.1463275252e+00
# номер итерации ф. Мадхавы-Лейбница -  331 число пи = 3.1446137947e+00
# номер итерации ф. Валлиса -  331 число пи = 3.1368790942e+00
# номер итерации ф. Мадхавы-Лейбница -  332 число пи = 3.1385806122e+00
# номер итерации ф. Валлиса -  332 число пи = 3.1462991515e+00
# номер итерации ф. Мадхавы-Лейбница -  333 число пи = 3.1445956498e+00
# номер итерации ф. Валлиса -  333 число пи = 3.1369072138e+00
# номер итерации ф. Мадхавы-Лейбница -  334 число пи = 3.1385986483e+00
# номер итерации ф. Валлиса -  334 число пи = 3.1462711159e+00
# номер итерации ф. Мадхавы-Лейбница -  335 число пи = 3.1445777216e+00
# номер итерации ф. Валлиса -  335 число пи = 3.1369349998e+00
# номер итерации ф. Мадхавы-Лейбница -  336 число пи = 3.1386164697e+00
# номер итерации ф. Валлиса -  336 число пи = 3.1462434123e+00
# номер итерации ф. Мадхавы-Лейбница -  337 число пи = 3.1445600061e+00
# номер итерации ф. Валлиса -  337 число пи = 3.1369624583e+00
# номер итерации ф. Мадхавы-Лейбница -  338 число пи = 3.1386340802e+00
# номер итерации ф. Валлиса -  338 число пи = 3.1462160348e+00
# номер итерации ф. Мадхавы-Лейбница -  339 число пи = 3.1445424997e+00
# номер итерации ф. Валлиса -  339 число пи = 3.1369895948e+00
# номер итерации ф. Мадхавы-Лейбница -  340 число пи = 3.1386514835e+00
# номер итерации ф. Валлиса -  340 число пи = 3.1461889778e+00
# номер итерации ф. Мадхавы-Лейбница -  341 число пи = 3.1445251986e+00
# номер итерации ф. Валлиса -  341 число пи = 3.1370164152e+00
# номер итерации ф. Мадхавы-Лейбница -  342 число пи = 3.1386686832e+00
# номер итерации ф. Валлиса -  342 число пи = 3.1461622357e+00
# номер итерации ф. Мадхавы-Лейбница -  343 число пи = 3.1445080993e+00
# номер итерации ф. Валлиса -  343 число пи = 3.1370429248e+00
# номер итерации ф. Мадхавы-Лейбница -  344 число пи = 3.1386856830e+00
# номер итерации ф. Валлиса -  344 число пи = 3.1461358029e+00
# номер итерации ф. Мадхавы-Лейбница -  345 число пи = 3.1444911982e+00
# номер итерации ф. Валлиса -  345 число пи = 3.1370691291e+00
# номер итерации ф. Мадхавы-Лейбница -  346 число пи = 3.1387024862e+00
# номер итерации ф. Валлиса -  346 число пи = 3.1461096741e+00
# номер итерации ф. Мадхавы-Лейбница -  347 число пи = 3.1444744920e+00
# номер итерации ф. Валлиса -  347 число пи = 3.1370950332e+00
# номер итерации ф. Мадхавы-Лейбница -  348 число пи = 3.1387190963e+00
# номер итерации ф. Валлиса -  348 число пи = 3.1460838442e+00
# номер итерации ф. Мадхавы-Лейбница -  349 число пи = 3.1444579772e+00
# номер итерации ф. Валлиса -  349 число пи = 3.1371206424e+00
# номер итерации ф. Мадхавы-Лейбница -  350 число пи = 3.1387355166e+00
# номер итерации ф. Валлиса -  350 число пи = 3.1460583080e+00
# номер итерации ф. Мадхавы-Лейбница -  351 число пи = 3.1444416507e+00
# номер итерации ф. Валлиса -  351 число пи = 3.1371459615e+00
# номер итерации ф. Мадхавы-Лейбница -  352 число пи = 3.1387517502e+00
# номер итерации ф. Валлиса -  352 число пи = 3.1460330606e+00
# номер итерации ф. Мадхавы-Лейбница -  353 число пи = 3.1444255091e+00
# номер итерации ф. Валлиса -  353 число пи = 3.1371709956e+00
# номер итерации ф. Мадхавы-Лейбница -  354 число пи = 3.1387678005e+00
# номер итерации ф. Валлиса -  354 число пи = 3.1460080970e+00
# номер итерации ф. Мадхавы-Лейбница -  355 число пи = 3.1444095494e+00
# номер итерации ф. Валлиса -  355 число пи = 3.1371957494e+00
# номер итерации ф. Мадхавы-Лейбница -  356 число пи = 3.1387836704e+00
# номер итерации ф. Валлиса -  356 число пи = 3.1459834126e+00
# номер итерации ф. Мадхавы-Лейбница -  357 число пи = 3.1443937685e+00
# номер итерации ф. Валлиса -  357 число пи = 3.1372202276e+00
# номер итерации ф. Мадхавы-Лейбница -  358 число пи = 3.1387993629e+00
# номер итерации ф. Валлиса -  358 число пи = 3.1459590026e+00
# номер итерации ф. Мадхавы-Лейбница -  359 число пи = 3.1443781635e+00
# номер итерации ф. Валлиса -  359 число пи = 3.1372444347e+00
# номер итерации ф. Мадхавы-Лейбница -  360 число пи = 3.1388148812e+00
# номер итерации ф. Валлиса -  360 число пи = 3.1459348625e+00
# номер итерации ф. Мадхавы-Лейбница -  361 число пи = 3.1443627314e+00
# номер итерации ф. Валлиса -  361 число пи = 3.1372683753e+00
# номер итерации ф. Мадхавы-Лейбница -  362 число пи = 3.1388302279e+00
# номер итерации ф. Валлиса -  362 число пи = 3.1459109879e+00
# номер итерации ф. Мадхавы-Лейбница -  363 число пи = 3.1443474693e+00
# номер итерации ф. Валлиса -  363 число пи = 3.1372920537e+00
# номер итерации ф. Мадхавы-Лейбница -  364 число пи = 3.1388454060e+00
# номер итерации ф. Валлиса -  364 число пи = 3.1458873744e+00
# номер итерации ф. Мадхавы-Лейбница -  365 число пи = 3.1443323745e+00
# номер итерации ф. Валлиса -  365 число пи = 3.1373154742e+00
# номер итерации ф. Мадхавы-Лейбница -  366 число пи = 3.1388604183e+00
# номер итерации ф. Валлиса -  366 число пи = 3.1458640177e+00
# номер итерации ф. Мадхавы-Лейбница -  367 число пи = 3.1443174442e+00
# номер итерации ф. Валлиса -  367 число пи = 3.1373386410e+00
# номер итерации ф. Мадхавы-Лейбница -  368 число пи = 3.1388752673e+00
# номер итерации ф. Валлиса -  368 число пи = 3.1458409137e+00
# ...
# номер итерации ф. Мадхавы-Лейбница -  879 число пи = 3.1427303096e+00
# номер итерации ф. Валлиса -  879 число пи = 3.1398101901e+00
# номер итерации ф. Мадхавы-Лейбница -  880 число пи = 3.1404562903e+00
# номер итерации ф. Валлиса -  880 число пи = 3.1433741063e+00
# номер итерации ф. Мадхавы-Лейбница -  881 число пи = 3.1427277270e+00
# номер итерации ф. Валлиса -  881 число пи = 3.1398142262e+00
# номер итерации ф. Мадхавы-Лейбница -  882 число пи = 3.1404588671e+00
# номер итерации ф. Валлиса -  882 число пи = 3.1433700747e+00
# номер итерации ф. Мадхавы-Лейбница -  883 число пи = 3.1427251561e+00
# номер итерации ф. Валлиса -  883 число пи = 3.1398182442e+00
# номер итерации ф. Мадхавы-Лейбница -  884 число пи = 3.1404614322e+00
# номер итерации ф. Валлиса -  884 число пи = 3.1433660614e+00
# номер итерации ф. Мадхавы-Лейбница -  885 число пи = 3.1427225967e+00
# номер итерации ф. Валлиса -  885 число пи = 3.1398222440e+00
# номер итерации ф. Мадхавы-Лейбница -  886 число пи = 3.1404639858e+00
# номер итерации ф. Валлиса -  886 число пи = 3.1433620661e+00
# номер итерации ф. Мадхавы-Лейбница -  887 число пи = 3.1427200489e+00
# номер итерации ф. Валлиса -  887 число пи = 3.1398262258e+00
# номер итерации ф. Мадхавы-Лейбница -  888 число пи = 3.1404665278e+00
# номер итерации ф. Валлиса -  888 число пи = 3.1433580888e+00
# номер итерации ф. Мадхавы-Лейбница -  889 число пи = 3.1427175126e+00
# номер итерации ф. Валлиса -  889 число пи = 3.1398301897e+00
# номер итерации ф. Мадхавы-Лейбница -  890 число пи = 3.1404690584e+00
# номер итерации ф. Валлиса -  890 число пи = 3.1433541293e+00
# номер итерации ф. Мадхавы-Лейбница -  891 число пи = 3.1427149877e+00
# номер итерации ф. Валлиса -  891 число пи = 3.1398341359e+00
# номер итерации ф. Мадхавы-Лейбница -  892 число пи = 3.1404715777e+00
# номер итерации ф. Валлиса -  892 число пи = 3.1433501875e+00
# номер итерации ф. Мадхавы-Лейбница -  893 число пи = 3.1427124741e+00
# номер итерации ф. Валлиса -  893 число пи = 3.1398380644e+00
# номер итерации ф. Мадхавы-Лейбница -  894 число пи = 3.1404740857e+00
# номер итерации ф. Валлиса -  894 число пи = 3.1433462634e+00
# номер итерации ф. Мадхавы-Лейбница -  895 число пи = 3.1427099717e+00
# номер итерации ф. Валлиса -  895 число пи = 3.1398419755e+00
# номер итерации ф. Мадхавы-Лейбница -  896 число пи = 3.1404765825e+00
# номер итерации ф. Валлиса -  896 число пи = 3.1433423567e+00
# номер итерации ф. Мадхавы-Лейбница -  897 число пи = 3.1427074804e+00
# номер итерации ф. Валлиса -  897 число пи = 3.1398458691e+00
# номер итерации ф. Мадхавы-Лейбница -  898 число пи = 3.1404790682e+00
# номер итерации ф. Валлиса -  898 число пи = 3.1433384674e+00
# номер итерации ф. Мадхавы-Лейбница -  899 число пи = 3.1427050003e+00
# номер итерации ф. Валлиса -  899 число пи = 3.1398497454e+00
# номер итерации ф. Мадхавы-Лейбница -  900 число пи = 3.1404815428e+00
# номер итерации ф. Валлиса -  900 число пи = 3.1433345953e+00
# номер итерации ф. Мадхавы-Лейбница -  901 число пи = 3.1427025312e+00
# номер итерации ф. Валлиса -  901 число пи = 3.1398536046e+00
# номер итерации ф. Мадхавы-Лейбница -  902 число пи = 3.1404840065e+00
# номер итерации ф. Валлиса -  902 число пи = 3.1433307404e+00
# номер итерации ф. Мадхавы-Лейбница -  903 число пи = 3.1427000730e+00
# номер итерации ф. Валлиса -  903 число пи = 3.1398574468e+00
# номер итерации ф. Мадхавы-Лейбница -  904 число пи = 3.1404864592e+00
# номер итерации ф. Валлиса -  904 число пи = 3.1433269025e+00
# номер итерации ф. Мадхавы-Лейбница -  905 число пи = 3.1426976256e+00
# номер итерации ф. Валлиса -  905 число пи = 3.1398612720e+00
# номер итерации ф. Мадхавы-Лейбница -  906 число пи = 3.1404889012e+00
# номер итерации ф. Валлиса -  906 число пи = 3.1433230815e+00
# номер итерации ф. Мадхавы-Лейбница -  907 число пи = 3.1426951891e+00
# номер итерации ф. Валлиса -  907 число пи = 3.1398650803e+00
# номер итерации ф. Мадхавы-Лейбница -  908 число пи = 3.1404913323e+00
# номер итерации ф. Валлиса -  908 число пи = 3.1433192774e+00
# номер итерации ф. Мадхавы-Лейбница -  909 число пи = 3.1426927633e+00
# номер итерации ф. Валлиса -  909 число пи = 3.1398688720e+00
# номер итерации ф. Мадхавы-Лейбница -  910 число пи = 3.1404937528e+00
# номер итерации ф. Валлиса -  910 число пи = 3.1433154899e+00
# номер итерации ф. Мадхавы-Лейбница -  911 число пи = 3.1426903481e+00
# номер итерации ф. Валлиса -  911 число пи = 3.1398726470e+00
# номер итерации ф. Мадхавы-Лейбница -  912 число пи = 3.1404961627e+00
# номер итерации ф. Валлиса -  912 число пи = 3.1433117190e+00
# номер итерации ф. Мадхавы-Лейбница -  913 число пи = 3.1426879435e+00
# номер итерации ф. Валлиса -  913 число пи = 3.1398764056e+00
# номер итерации ф. Мадхавы-Лейбница -  914 число пи = 3.1404985620e+00
# номер итерации ф. Валлиса -  914 число пи = 3.1433079645e+00
# номер итерации ф. Мадхавы-Лейбница -  915 число пи = 3.1426855494e+00
# номер итерации ф. Валлиса -  915 число пи = 3.1398801478e+00
# номер итерации ф. Мадхавы-Лейбница -  916 число пи = 3.1405009509e+00
# номер итерации ф. Валлиса -  916 число пи = 3.1433042264e+00
# номер итерации ф. Мадхавы-Лейбница -  917 число пи = 3.1426831658e+00
# номер итерации ф. Валлиса -  917 число пи = 3.1398838736e+00
# номер итерации ф. Мадхавы-Лейбница -  918 число пи = 3.1405033293e+00
# номер итерации ф. Валлиса -  918 число пи = 3.1433005046e+00
# номер итерации ф. Мадхавы-Лейбница -  919 число пи = 3.1426807925e+00
# номер итерации ф. Валлиса -  919 число пи = 3.1398875833e+00
# номер итерации ф. Мадхавы-Лейбница -  920 число пи = 3.1405056974e+00
# номер итерации ф. Валлиса -  920 число пи = 3.1432967989e+00
# номер итерации ф. Мадхавы-Лейбница -  921 число пи = 3.1426784296e+00
# номер итерации ф. Валлиса -  921 число пи = 3.1398912770e+00
# номер итерации ф. Мадхавы-Лейбница -  922 число пи = 3.1405080552e+00
# номер итерации ф. Валлиса -  922 число пи = 3.1432931093e+00
# номер итерации ф. Мадхавы-Лейбница -  923 число пи = 3.1426760769e+00
# номер итерации ф. Валлиса -  923 число пи = 3.1398949546e+00
# номер итерации ф. Мадхавы-Лейбница -  924 число пи = 3.1405104028e+00
# номер итерации ф. Валлиса -  924 число пи = 3.1432894356e+00
# номер итерации ф. Мадхавы-Лейбница -  925 число пи = 3.1426737344e+00
# номер итерации ф. Валлиса -  925 число пи = 3.1398986164e+00
# номер итерации ф. Мадхавы-Лейбница -  926 число пи = 3.1405127403e+00
# номер итерации ф. Валлиса -  926 число пи = 3.1432857778e+00
# номер итерации ф. Мадхавы-Лейбница -  927 число пи = 3.1426714019e+00
# номер итерации ф. Валлиса -  927 число пи = 3.1399022624e+00
# номер итерации ф. Мадхавы-Лейбница -  928 число пи = 3.1405150677e+00
# номер итерации ф. Валлиса -  928 число пи = 3.1432821357e+00
# номер итерации ф. Мадхавы-Лейбница -  929 число пи = 3.1426690795e+00
# номер итерации ф. Валлиса -  929 число пи = 3.1399058928e+00
# номер итерации ф. Мадхавы-Лейбница -  930 число пи = 3.1405173851e+00
# номер итерации ф. Валлиса -  930 число пи = 3.1432785092e+00
# номер итерации ф. Мадхавы-Лейбница -  931 число пи = 3.1426667671e+00
# номер итерации ф. Валлиса -  931 число пи = 3.1399095076e+00
# номер итерации ф. Мадхавы-Лейбница -  932 число пи = 3.1405196925e+00
# номер итерации ф. Валлиса -  932 число пи = 3.1432748983e+00
# номер итерации ф. Мадхавы-Лейбница -  933 число пи = 3.1426644646e+00
# номер итерации ф. Валлиса -  933 число пи = 3.1399131070e+00
# номер итерации ф. Мадхавы-Лейбница -  934 число пи = 3.1405219901e+00
# номер итерации ф. Валлиса -  934 число пи = 3.1432713028e+00
# номер итерации ф. Мадхавы-Лейбница -  935 число пи = 3.1426621720e+00
# номер итерации ф. Валлиса -  935 число пи = 3.1399166909e+00
# номер итерации ф. Мадхавы-Лейбница -  936 число пи = 3.1405242778e+00
# номер итерации ф. Валлиса -  936 число пи = 3.1432677226e+00
# номер итерации ф. Мадхавы-Лейбница -  937 число пи = 3.1426598891e+00
# номер итерации ф. Валлиса -  937 число пи = 3.1399202597e+00
# номер итерации ф. Мадхавы-Лейбница -  938 число пи = 3.1405265558e+00
# номер итерации ф. Валлиса -  938 число пи = 3.1432641577e+00
# номер итерации ф. Мадхавы-Лейбница -  939 число пи = 3.1426576160e+00
# номер итерации ф. Валлиса -  939 число пи = 3.1399238132e+00
# номер итерации ф. Мадхавы-Лейбница -  940 число пи = 3.1405288241e+00
# номер итерации ф. Валлиса -  940 число пи = 3.1432606079e+00
# номер итерации ф. Мадхавы-Лейбница -  941 число пи = 3.1426553525e+00
# номер итерации ф. Валлиса -  941 число пи = 3.1399273517e+00
# номер итерации ф. Мадхавы-Лейбница -  942 число пи = 3.1405310828e+00
# номер итерации ф. Валлиса -  942 число пи = 3.1432570732e+00
# номер итерации ф. Мадхавы-Лейбница -  943 число пи = 3.1426530987e+00
# номер итерации ф. Валлиса -  943 число пи = 3.1399308752e+00
# номер итерации ф. Мадхавы-Лейбница -  944 число пи = 3.1405333319e+00
# номер итерации ф. Валлиса -  944 число пи = 3.1432535534e+00
# номер итерации ф. Мадхавы-Лейбница -  945 число пи = 3.1426508544e+00
# номер итерации ф. Валлиса -  945 число пи = 3.1399343839e+00
# номер итерации ф. Мадхавы-Лейбница -  946 число пи = 3.1405355714e+00
# номер итерации ф. Валлиса -  946 число пи = 3.1432500485e+00
# номер итерации ф. Мадхавы-Лейбница -  947 число пи = 3.1426486195e+00
# номер итерации ф. Валлиса -  947 число пи = 3.1399378777e+00
# номер итерации ф. Мадхавы-Лейбница -  948 число пи = 3.1405378016e+00
# номер итерации ф. Валлиса -  948 число пи = 3.1432465583e+00
# номер итерации ф. Мадхавы-Лейбница -  949 число пи = 3.1426463941e+00
# номер итерации ф. Валлиса -  949 число пи = 3.1399413569e+00
# номер итерации ф. Мадхавы-Лейбница -  950 число пи = 3.1405400223e+00
# номер итерации ф. Валлиса -  950 число пи = 3.1432430828e+00
# номер итерации ф. Мадхавы-Лейбница -  951 число пи = 3.1426441780e+00
# номер итерации ф. Валлиса -  951 число пи = 3.1399448214e+00
# номер итерации ф. Мадхавы-Лейбница -  952 число пи = 3.1405422337e+00
# номер итерации ф. Валлиса -  952 число пи = 3.1432396219e+00
# номер итерации ф. Мадхавы-Лейбница -  953 число пи = 3.1426419712e+00
# номер итерации ф. Валлиса -  953 число пи = 3.1399482715e+00
# номер итерации ф. Мадхавы-Лейбница -  954 число пи = 3.1405444358e+00
# номер итерации ф. Валлиса -  954 число пи = 3.1432361754e+00
# номер итерации ф. Мадхавы-Лейбница -  955 число пи = 3.1426397737e+00
# номер итерации ф. Валлиса -  955 число пи = 3.1399517071e+00
# номер итерации ф. Мадхавы-Лейбница -  956 число пи = 3.1405466288e+00
# номер итерации ф. Валлиса -  956 число пи = 3.1432327434e+00
# номер итерации ф. Мадхавы-Лейбница -  957 число пи = 3.1426375854e+00
# номер итерации ф. Валлиса -  957 число пи = 3.1399551284e+00
# номер итерации ф. Мадхавы-Лейбница -  958 число пи = 3.1405488125e+00
# номер итерации ф. Валлиса -  958 число пи = 3.1432293256e+00
# номер итерации ф. Мадхавы-Лейбница -  959 число пи = 3.1426354062e+00
# номер итерации ф. Валлиса -  959 число пи = 3.1399585355e+00
# номер итерации ф. Мадхавы-Лейбница -  960 число пи = 3.1405509872e+00
# номер итерации ф. Валлиса -  960 число пи = 3.1432259221e+00
# номер итерации ф. Мадхавы-Лейбница -  961 число пи = 3.1426332360e+00
# номер итерации ф. Валлиса -  961 число пи = 3.1399619284e+00
# номер итерации ф. Мадхавы-Лейбница -  962 число пи = 3.1405531528e+00
# номер итерации ф. Валлиса -  962 число пи = 3.1432225327e+00
# номер итерации ф. Мадхавы-Лейбница -  963 число пи = 3.1426310749e+00
# номер итерации ф. Валлиса -  963 число пи = 3.1399653073e+00
# номер итерации ф. Мадхавы-Лейбница -  964 число пи = 3.1405553095e+00
# номер итерации ф. Валлиса -  964 число пи = 3.1432191574e+00
# номер итерации ф. Мадхавы-Лейбница -  965 число пи = 3.1426289227e+00
# номер итерации ф. Валлиса -  965 число пи = 3.1399686722e+00
# номер итерации ф. Мадхавы-Лейбница -  966 число пи = 3.1405574572e+00
# номер итерации ф. Валлиса -  966 число пи = 3.1432157959e+00
# номер итерации ф. Мадхавы-Лейбница -  967 число пи = 3.1426267795e+00
# номер итерации ф. Валлиса -  967 число пи = 3.1399720232e+00
# номер итерации ф. Мадхавы-Лейбница -  968 число пи = 3.1405595960e+00
# номер итерации ф. Валлиса -  968 число пи = 3.1432124484e+00
# номер итерации ф. Мадхавы-Лейбница -  969 число пи = 3.1426246451e+00
# номер итерации ф. Валлиса -  969 число пи = 3.1399753604e+00
# номер итерации ф. Мадхавы-Лейбница -  970 число пи = 3.1405617260e+00
# номер итерации ф. Валлиса -  970 число пи = 3.1432091146e+00
# номер итерации ф. Мадхавы-Лейбница -  971 число пи = 3.1426225194e+00
# номер итерации ф. Валлиса -  971 число пи = 3.1399786839e+00
# номер итерации ф. Мадхавы-Лейбница -  972 число пи = 3.1405638473e+00
# номер итерации ф. Валлиса -  972 число пи = 3.1432057946e+00
# номер итерации ф. Мадхавы-Лейбница -  973 число пи = 3.1426204025e+00
# номер итерации ф. Валлиса -  973 число пи = 3.1399819937e+00
# номер итерации ф. Мадхавы-Лейбница -  974 число пи = 3.1405659598e+00
# номер итерации ф. Валлиса -  974 число пи = 3.1432024881e+00
# номер итерации ф. Мадхавы-Лейбница -  975 число пи = 3.1426182943e+00
# номер итерации ф. Валлиса -  975 число пи = 3.1399852901e+00
# номер итерации ф. Мадхавы-Лейбница -  976 число пи = 3.1405680637e+00
# номер итерации ф. Валлиса -  976 число пи = 3.1431991952e+00
# номер итерации ф. Мадхавы-Лейбница -  977 число пи = 3.1426161948e+00
# номер итерации ф. Валлиса -  977 число пи = 3.1399885729e+00
# номер итерации ф. Мадхавы-Лейбница -  978 число пи = 3.1405701590e+00
# номер итерации ф. Валлиса -  978 число пи = 3.1431959157e+00
# номер итерации ф. Мадхавы-Лейбница -  979 число пи = 3.1426141038e+00
# номер итерации ф. Валлиса -  979 число пи = 3.1399918424e+00
# номер итерации ф. Мадхавы-Лейбница -  980 число пи = 3.1405722457e+00
# номер итерации ф. Валлиса -  980 число пи = 3.1431926495e+00
# номер итерации ф. Мадхавы-Лейбница -  981 число пи = 3.1426120213e+00
# номер итерации ф. Валлиса -  981 число пи = 3.1399950985e+00
# номер итерации ф. Мадхавы-Лейбница -  982 число пи = 3.1405743239e+00
# номер итерации ф. Валлиса -  982 число пи = 3.1431893967e+00
# номер итерации ф. Мадхавы-Лейбница -  983 число пи = 3.1426099473e+00
# номер итерации ф. Валлиса -  983 число пи = 3.1399983415e+00
# номер итерации ф. Мадхавы-Лейбница -  984 число пи = 3.1405763937e+00
# номер итерации ф. Валлиса -  984 число пи = 3.1431861570e+00
# номер итерации ф. Мадхавы-Лейбница -  985 число пи = 3.1426078818e+00
# номер итерации ф. Валлиса -  985 число пи = 3.1400015713e+00
# номер итерации ф. Мадхавы-Лейбница -  986 число пи = 3.1405784551e+00
# номер итерации ф. Валлиса -  986 число пи = 3.1431829305e+00
# номер итерации ф. Мадхавы-Лейбница -  987 число пи = 3.1426058246e+00
# номер итерации ф. Валлиса -  987 число пи = 3.1400047880e+00
# номер итерации ф. Мадхавы-Лейбница -  988 число пи = 3.1405805081e+00
# номер итерации ф. Валлиса -  988 число пи = 3.1431797170e+00
# номер итерации ф. Мадхавы-Лейбница -  989 число пи = 3.1426037757e+00
# номер итерации ф. Валлиса -  989 число пи = 3.1400079918e+00
# номер итерации ф. Мадхавы-Лейбница -  990 число пи = 3.1405825528e+00
# номер итерации ф. Валлиса -  990 число пи = 3.1431765165e+00
# номер итерации ф. Мадхавы-Лейбница -  991 число пи = 3.1426017351e+00
# номер итерации ф. Валлиса -  991 число пи = 3.1400111826e+00
# номер итерации ф. Мадхавы-Лейбница -  992 число пи = 3.1405845893e+00
# номер итерации ф. Валлиса -  992 число пи = 3.1431733288e+00
# номер итерации ф. Мадхавы-Лейбница -  993 число пи = 3.1425997027e+00
# номер итерации ф. Валлиса -  993 число пи = 3.1400143607e+00
# номер итерации ф. Мадхавы-Лейбница -  994 число пи = 3.1405866176e+00
# номер итерации ф. Валлиса -  994 число пи = 3.1431701540e+00
# номер итерации ф. Мадхавы-Лейбница -  995 число пи = 3.1425976785e+00
# номер итерации ф. Валлиса -  995 число пи = 3.1400175260e+00
# номер итерации ф. Мадхавы-Лейбница -  996 число пи = 3.1405886378e+00
# номер итерации ф. Валлиса -  996 число пи = 3.1431669919e+00
# номер итерации ф. Мадхавы-Лейбница -  997 число пи = 3.1425956624e+00
# номер итерации ф. Валлиса -  997 число пи = 3.1400206786e+00
# номер итерации ф. Мадхавы-Лейбница -  998 число пи = 3.1405906498e+00
# номер итерации ф. Валлиса -  998 число пи = 3.1431638424e+00
# номер итерации ф. Мадхавы-Лейбница -  999 число пи = 3.1425936543e+00
# номер итерации ф. Валлиса -  999 число пи = 3.1400238186e+00
# номер итерации ф. Мадхавы-Лейбница -  1000 число пи = 3.1405926538e+00
# номер итерации ф. Валлиса -  1000 число пи = 3.1431607055e+00

# %% [markdown]
# # Домашнее задание (базовое):

# %% [markdown]
# # Задание 1. Счастливое число

# %% [markdown]
# Дано четырехзначное число. Определите, является ли его десятичная запись симметричной. Если число симметричное, то выведите 1, иначе выведите любое другое целое число. Число может иметь меньше четырех знаков, тогда нужно считать, что его десятичная запись дополняется слева нулями.

# %%
n=input('Введите четырехзначное число ')
n=float(n)
if 0.1<n/1000<1:
    n=n*10
elif 0.1>n/1000:
    n=n*100
elif 0.01>n/1000:
    n=n*1000
y=n%100
y=float(y)
z=n//100
z=float(z)
if (y==z):
    print("1")
else:
    print('0')
# Out:
# Введите четырехзначное число 1
# 0

# %% [markdown]
# # Задание 2. Високосный год

# %% [markdown]
# Дано натуральное число. Требуется определить, является ли год с данным номером високосным. Если год является високосным, то выведите YES, иначе выведите NO. Напомним, что в соответствии с григорианским календарем, год является високосным, если его номер кратен 4, но не кратен 100, или же если он кратен 400.

# %%
n=input("Введите число ")
n=float(n)
if n%4==0 and n%100!=0 or n%400==0:
    print("True")
else:
    print("False")
# Out:
# Введите число 300
# False

# %% [markdown]
# # Задание 3. Коровы

# %% [markdown]
# Для целого числа n введённого пользователем закончите фразу “На лугу пасется...” одним из возможных продолжений: “n коров”, “n корова”, “n коровы”, правильно склоняя слово “корова”.

# %%
n=input('Введите количество коров ')
n=int(n)
if 10<=n%100<20 or 10<=n<20:
    print('На лугу пасется %i коров' %(n))
elif n%10==1:
    print('На лугу пасется %i коровa' %(n))
elif 2<=n%10<=4:
    print('На лугу пасется %i коровы' %(n))
elif 5<=n%10<10:
    print('На лугу пасется %i коров' %(n))
elif n%10==0:
    print('На лугу пасется %i коров' %(n))
# Out:
# Введите количество коров 23
# На лугу пасется 23 коровы

# %% [markdown]
# # Задание 4. Минимальный делитель

# %% [markdown]
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.
# Напишите программу в 2-х вариантах - с помощью цикла for и while.

# %%
n=input()
n=int(n)
d=2
while n%d!=0:
    d+=1
print(d)

for d in range(2, n+1):
    if not n % d:
        print(d)
        break
# Out:
# 67464772
# 2
# 2

# %% [markdown]
# # Задание 5. Последовательность

# %% [markdown]
# Программа получает на вход последовательность целых неотрицательных чисел, каждое число записано в отдельной строке. Последовательность завершается числом 0, при считывании которого программа должна закончить свою работу и вывести количество членов последовательности (не считая завершающего числа 0).
# После завершения ввода данных программа запрашивает пользователя какую операцию с ними нужно выполнить:
#
# 1. Найти сумму введённых чисел.
# 2. Найти произведение введённых чисел.
# 3. Найти среднее значение введённых чисел.
# 4. Найти максимальное из введённых чисел.
# 5. Найти минимальное из введённых чисел.
# 6. Определить количество чётных и нечётных эллементов.
#
# После получения ответа от пользователя программа выполняет расчёт и выводит результат.

# %%
n=input('Введите первое натуральное число ')
n=float(n)
s=0
p=1
k=0
y=0
v=0
z=-1
l=float('inf')
while n != 0:
    s=s+n
    p=p*n
    m=n
    if n%2==0:
        y+=1
    elif n%2==1:
        v+=1
    if n>z:
        z=n
    elif l>n:
        l=n
    n=input()
    n=float(n)
    k=k+1 
r=input("Введите номер команды: Найти сумму введённых чисел - 1, Найти произведение введённых чисел - 2, Найти среднее значение введённых чисел - 3, Найти максимальное из введённых чисел - 4, Найти минимальное из введённых чисел - 5, Определить количество чётных и нечётных эллементов - 6 ")
r=float(r)
if r==1:
    print(s)
elif r==2:
    print(p)
elif r==3:
    print(s/k)
elif r==4:
    print(z)
elif r==5:
    print(l)
elif r==6:
    print("Четных элементов ", y, "Нечетных элементов ", v)
del l
# Out:
# Введите первое натуральное число 3
# 7
# 2
# 8
# 0
# Введите номер команды: Найти сумму введённых чисел - 1, Найти произведение введённых чисел - 2, Найти среднее значение введённых чисел - 3, Найти максимальное из введённых чисел - 4, Найти минимальное из введённых чисел - 5, Определить количество чётных и нечётных эллементов - 6 5
# 2.0

# %% [markdown]
# ###### Домашнее задание (дополнительное):

# %% [markdown]
# ### Задание. "Без всяких условностей"

# %% [markdown]
# Напишите программу, которая принимает два целых числа A и B и выводит наибольшее значение из них.
#
# При решении задачи можно пользоваться только целочисленными арифметическими операциями. Нельзя пользоваться нелинейными конструкциями: ветвлениями, циклами, функциями.

# %%
input(a)
input(b)

# %% [markdown]
# # Задание. "Котлеты"

# %% [markdown]
# На сковородку одновременно можно положить k котлет. Каждую котлету нужно с каждой стороны обжаривать m минут непрерывно. За какое наименьшее время удастся поджарить с обеих сторон n котлет?
# Программа получает на вход три числа: k,m,n. И выводит одно число: наименьшее количество минут.

# %%
i = 0
while i < 5:
    print('*')
    if i % 2 == 0:
        print('**')
    if i > 2:
        print('***')
    i = i + 1
# Out:
# *
# **
# *
# *
# **
# *
# ***
# *
# **
# ***

# %% [markdown]
# # Задание. "Угадай число"

# %% [markdown]
# Пользователь загадывает число от 1 до N. Программа запрашивает у пользователя N. Требуется отгадать загаданное число, задав как можно меньше вопросов. (Обычно подобные задачи решают с помощью цикла).
